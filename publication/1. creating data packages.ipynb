# %%
from premise import *
import bw2data
from datapackage import Package
bw2data.projects.set_current("ei310")

# %%
sps = Package("../datapackage.json")
scenarios = [
    {"model": "remind", "pathway": "SSP2-NPi", "year": 2020, "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2030, "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2040, "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2050, "external scenarios": [{"scenario": "SPS1", "data": sps}]},
]

ndb = NewDatabase(
        scenarios=scenarios,
        source_db="ecoinvent-3.10-cutoff", # <-- name of the database in the BW2 project. Must be a string.
        source_version="3.10", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
        key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
        use_absolute_efficiency=True,
        biosphere_name="ecoinvent-3.10-biosphere"
        
)

ndb.update()

ndb.write_db_to_brightway("2020")
# Out:
# premise v.(2, 1, 1, 'dev0')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Done!
# Processing scenarios:   0%|                     | 0/1 [00:00<?, ?it/s]
# Extracted 1 worksheets in 0.07 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, photovoltaic, commercial  |              electricity, low voltage              |
# | electricity production, photovoltaic, residential  |              electricity, low voltage              |
# | electricity, residential, by conversion of hydroge |    electricity, from residential heating system    |
# | electricity supply, high voltage, from vanadium-re |             electricity, high voltage              |
# | electricity supply, from stationary 19.5 kWh NMC b |             electricity, high voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (multi family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (multi family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (services CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (services CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702241501104394.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702241501104394.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732017350993954.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732017350993954.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442297392757496.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442297392757496.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702241501104394.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702241501104394.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732017350993954.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732017350993954.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442297392757496.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442297392757496.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Processing scenarios: 100%|████████████| 1/1 [01:59<00:00, 119.71s/it]
# Done!
#
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Database 2020 already exists: it will be overwritten.
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:31
# Title: Writing activities to SQLite3 database:
#   Started: 06/15/2024 17:39:26
#   Finished: 06/15/2024 17:39:57
#   Total time elapsed: 00:00:31
#   CPU %: 91.80
#   Memory %: 23.32
# Created database: 2020
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev.

# %%
a = [
    'compressed gas, burned in heavy duty vehicle',
    'compressed gas, burned in passenger car vehicle',
    'compressed gas, burned in passenger car vehicle_FE_light_duty_truck_gas',
    'compressed gas, burned in single deck coach or urban bus',
    'compressed gas, burned in single deck coach or urban bus_FE_coach_gas',
    'diesel, burned in heavy duty vehicle',
    'diesel, burned in passenger car vehicle',
    'diesel, burned in passenger car vehicle_FE_light_duty_truck_diesel',
    'diesel, burned in passenger car vehicle_FE_other_transport_diesel',
    'diesel, burned in single deck coach or urban bus',
    'diesel, burned in single deck coach or urban bus_FE_coach_diesel',
    'electricity, used in battery electric motorcycle',
    'electricity, used in heavy duty vehicle',
    'electricity, used in industrial electric boiler',
    'electricity, used in industrial electric boiler_FE_services_electric_boiler',
    'electricity, used in industrial electric processes',
    'electricity, used in industrial electric processes_FE_services_FE_other_electric',
    'electricity, used in industrial heat pump',
    'electricity, used in industrial heat pump_FE_services_heat_pump',
    'electricity, used in passenger car vehicle',
    'electricity, used in passenger car vehicle_FE_light_duty_truck_electricity',
    'electricity, used in passenger car vehicle_FE_other_transport_electric',
    'electricity, used in residential electric appliances',
    'electricity, used in residential electric boiler',
    'electricity, used in residential electric boiler_FE_residential_water_heating_electric_boiler',
    'electricity, used in residential heat pump',
    'electricity, used in residential heat pump_FE_residential_water_heating_heat_pump',
    'electricity, used in single deck coach or urban bus',
    'electricity, used in single deck coach or urban bus_FE_coach_electricity',
    'electricity, used in single deck trolleybus',
    'electricity, used in tram',
    'hard coal, burned in hard coal industrial furnace 1-10MW',
    'hard coal, burned in hard coal residential boiler 5-15kW',
    'hard coal, burned in hard coal residential boiler 5-15kW_FE_residential_water_heating_coal',
    'heavy fuel oil, burned in industrial furnace 1MW',
    'heavy fuel oil, burned in refinery furnace',
    'hydrogen burned, in hydrogen boiler',
    'hydrogen burned, in hydrogen boiler_FE_residential_space_heating_hydrogen',
    'hydrogen burned, in hydrogen boiler_FE_residential_water_heating_hydrogen',
    'hydrogen burned, in hydrogen boiler_FE_services_hydrogen',
    'hydrogen, used in heavy duty vehicle',
    'hydrogen, used in hydrogen motorcycle',
    'hydrogen, used in passenger car vehicle',
    'hydrogen, used in passenger car vehicle_FE_light_duty_truck_hydrogen',
    'hydrogen, used in passenger car vehicle_FE_other_transport_hydrogen',
    'hydrogen, used in single deck coach or urban bus',
    'hydrogen, used in single deck coach or urban bus_FE_coach_hydrogen',
    'light fuel oil, burned in industrial furnace 1MW',
    'light fuel oil, burned in industrial furnace 1MW_FE_services_light_fuel_oil',
    'light fuel oil, burned in residential 10kW boiler',
    'light fuel oil, burned in residential 10kW boiler_FE_residential_water_heating_light_fuel_oil',
    'market for energy carriers for buses (SPS)',
    'market for energy carriers for cars (SPS)',
    'market for energy carriers for coaches (SPS)',
    'market for energy carriers for heavy duty trucks (SPS)',
    'market for energy carriers for light duty trucks (SPS)',
    'market for energy carriers for motorcycles (SPS)',
    'market for energy carriers for other transport (SPS)',
    'natural gas, burned in industrial furnace >100kW',
    'natural gas, burned in industrial furnace >100kW_FE_services_natural_gas',
    'natural gas, burned in micro gas turbine, 100kWe',
    'natural gas, burned in polymer electrolyte membrane fuel cell 2kWe, future',
    'natural gas, burned in residential natural gas boiler <100kW',
    'natural gas, burned in residential natural gas boiler <100kW_FE_residential_space_heating_heat_pump_gas',
    'natural gas, burned in residential natural gas boiler <100kW_FE_residential_water_heating_gas',
    'natural gas, burned in residential natural gas boiler <100kW_FE_residential_water_heating_heat_pump_gas',
    'natural gas, burned in solid oxide fuel cell 125kWe, future',
    'natural gas, burned in solid oxide fuel cell, with micro gas turbine, 180kWe, future',
    'pellet, burned in pellet industrial furnace 300kW',
    'pellet, burned in pellet industrial furnace 300kW_FE_services_pellet',
    'pellet, burned in residential pellet stove 5-15kW',
    'pellet, burned in residential pellet stove 5-15kW_FE_residential_water_heating_pellet',
    'petrol, burned in motorcycle',
    'petrol, burned in passenger car vehicle',
    'petrol, burned in passenger car vehicle_FE_heavy_duty_truck_gasoline',
    'petrol, burned in passenger car vehicle_FE_light_duty_truck_gasoline',
    'petrol, burned in passenger car vehicle_FE_other_transport_gasoline',
    'solar energy, from industrial hot water tank',
    'solar energy, from industrial hot water tank_FE_services_solar',
    'solar energy, from residential hot water tank',
    'solar energy, from residential hot water tank_FE_residential_water_heating_solar',
    'wood, burned in residential wood stove 5-15kW',
    'wood, burned in residential wood stove 5-15kW_FE_residential_water_heating_wood',
    'wood, burned in wood industrial furnace 1-10MW',
    'wood, burned in wood industrial furnace 1-10MW_FE_services_wood',
    'market for water heating in residential (SPS)',
    'market for space and water heating in residential (SPS)',
    'market for process heat in industry (SPS)',
    'market for process heat and space heating in industry (SPS)',
    'market for space heating in residential (SPS)',
    'market for space heating in industry (SPS)',
    'market for space heating in services (SPS)',
    'market for district heating (SPS)',
    'heat, from on-site industrial wood-fired CHP with CCS',
    'heat, from on-site industrial gas-fired CHP_FE_services_CHP_gas',
    'heat, from on-site residential wood-fired CHP',
    'heat, from on-site industrial fuel cell CHP_FE_services_CHP_fuel_cell',
    'heat, from on-site industrial non-renewable waste-fired CHP with CCS',
    'heat, from on-site industrial gas-fired CHP with CCS',
    'heat, from on-site industrial biogas-fired CHP',
    'heat, from on-site residential gas-fired CHP',
    'heat, from on-site industrial hydrogen-fired CHP_FE_services_CHP_hydrogen',
    'heat, from on-site industrial hydrogen-fired CHP',
    'heat, from on-site industrial fuel cell CHP',
    'heat, from on-site residential fuel cell CHP',
    'heat, from on-site industrial wood-fired CHP',
    'heat, from on-site industrial gas-fired CHP',
    'heat, from nuclear power plant',
    'heat, from on-site industrial wood-fired CHP_FE_services_CHP_wood',
    'heat, from on-site industrial non-renewable waste-fired CHP',
    'heat, from on-site industrial oil-fired CHP',
    'heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas',
    'heat production, at co-generation biowaste-fired power plant, post, pipeline 200km, storage 1000m',
    'heat production, from incineration of plastic waste mixture, energy allocation',
    'heat production, at co-generation plastic waste-fired power plant, post, pipeline 200km, storage 1000m',
    'heat, residential, by combustion of hydrogen using CHP, allocated by exergy, distributed by pipeline, produced by Electrolysis, PEM using electricity from grid',
]

# %%
methods = [
    ('EF v3.1 EN15804', 'climate change', 'global warming potential (GWP100)'),
    ('ReCiPe 2016 v1.03, endpoint (I)', 'total: ecosystem quality', 'ecosystem quality'),
    ('EF v3.1', 'material resources: metals/minerals', 'abiotic depletion potential (ADP): elements (ultimate reserves)'),
    ('Ecological Scarcity 2021', 'total - UBP'),
    ('ReCiPe 2016 v1.03, endpoint (E)', 'total: human health', 'human health'),
    ('selected LCI results', 'resource', 'land occupation'),
    ('Cumulative Energy Demand (CED)', 'energy resources: renewable', 'energy content (HHV)'),
    ('Cumulative Energy Demand (CED)', 'energy resources: non-renewable', 'energy content (HHV)'),
]

# %%
bw2data.calculation_setups["ankita"] = {"inv": FU, "ia": methods}

# %%
ndb.write_db_to_brightway("2050 2")
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:37
# Title: Writing activities to SQLite3 database:
#   Started: 06/12/2024 15:16:34
#   Finished: 06/12/2024 15:17:11
#   Total time elapsed: 00:00:37
#   CPU %: 97.10
#   Memory %: 17.12
# Created database: 2050 2
# Generate scenario report.
# Report saved under /Users/romain/Github/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/Github/sweet_sure-2050-switzerland/dev.

# %%
from premise import *
import bw2data
from datapackage import Package
bw2data.projects.set_current("ecoinvent-3.10-cutoff")

# %%
#clear_inventory_cache()
sps = Package("../datapackage.json")
scenarios=[
    #{"model": "remind", "pathway": "SSP2-NPi", "external scenarios": [{"scenario": "SPS4", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS4", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg500", "external scenarios": [{"scenario": "SPS4", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-NPi", "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg500", "external scenarios": [{"scenario": "SPS1", "data": sps}]},
]

for scenario in scenarios:
    name=f"{scenario['model']}-{scenario['pathway']}-stem-{scenario['external scenarios'][0]['scenario']}"
    print(name)
    ndb = PathwaysDataPackage(
        scenarios=[
            scenario,
        ],
        #years=[
        #    2020, 
        #    2050
        #],
        years=[
            2020,
            #2025,
            2030,
            #2035,
            2040,
            #2045,
            2050
        ],
        source_db="ecoinvent-3.10-cutoff", # <-- name of the database in the BW2 project. Must be a string.
        source_version="3.10", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
        key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
        use_absolute_efficiency=True,
        biosphere_name="biosphere3"
    )
    
    ndb.create_datapackage(
        name=name,
        contributors=[
            {"name": "Romain",
            "email": "r_s at me.com",}
        ],
    )
# Out:
# remind-SSP2-PkBudg1150-stem-SPS4
# premise v.(2, 1, 5)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Done!
# Processing scenarios for all sectors:   0%|     | 0/4 [00:00<?, ?it/s]
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702237868987347.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702237868987347.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732014082088612.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732014082088612.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442294545963056.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442294545963056.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1923509395896574.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1923509395896574.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.502112898597299.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.502112898597299.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2519016087375694.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2519016087375694.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.28726415094339613and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.28726415094339613and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.522245831and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.522245831and expected efficiency is 0.0.
# Processing scenarios for all sectors:  25%|▎| 1/4 [02:14<06:44, 134.92
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2390758218928553.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2390758218928553.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.538735103645751.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.538735103645751.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.284861593281176.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.284861593281176.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3070754716981132and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3070754716981132and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.53and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.53and expected efficiency is 0.0.
# Processing scenarios for all sectors:  50%|▌| 2/4 [04:31<04:31, 135.70
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2244533539682054.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2244533539682054.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5272742504075123.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5272742504075123.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.274546825366761.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.274546825366761.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3268867924528302and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3268867924528302and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.55and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.55and expected efficiency is 0.0.
# Processing scenarios for all sectors:  75%|▊| 3/4 [06:59<02:21, 141.69
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, natural gas, combined cycl in CH is 32.290936579918586.
# Warning: Efficiency factor for electricity production, natural gas, combined cycl in CH is 32.290936579918586.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.679615626742353.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 160kW electrical, Jakobsberg_gas (single family CHP fuel cell) in CH is 0.3825704746211224and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.6542301190995548.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.6542301190995548.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.864126309564516.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.864126309564516.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.577713678608064.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.577713678608064.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3466981132075472and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3466981132075472and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.56and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.56and expected efficiency is 0.0.
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for kerosene (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 4/4 [09:36<00:00, 144.05
# Done!
#
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2050.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/publication.
# Leaving out SE|Electricity|Gas|++|Gas Turbine from Gas ST
# Leaving out SE|Liquids|+|Hydrogen from diesel, synthetic, from electrolysis
# Leaving out SE|Liquids|Fossil|Coal|+|w/o CC from diesel, synthetic, from coal
# Leaving out SE|Liquids|Fossil|Coal|+|w/ CC from diesel, synthetic, from coal, with CCS
# Data package saved at /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/remind-SSP2-PkBudg1150-stem-SPS4.zip
# remind-SSP2-PkBudg500-stem-SPS4
# premise v.(2, 1, 5)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Done!
# Processing scenarios for all sectors:   0%|     | 0/4 [00:00<?, ?it/s]
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# ...
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.6300408311465255.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 1.6300408311465255.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.459296827037334.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.459296827037334.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.711340756326559.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.711340756326559.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.4402066806939033.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.4402066806939033.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.03672477417735.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.03672477417735.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.263302490575404.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.263302490575404.
# Processing scenarios for all sectors:  75%|▊| 3/4 [14:46<04:58, 298.97
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.290456400318506.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.290456400318506.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 4.805652315668724.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 4.805652315668724.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 3.7665923555241347.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 3.7665923555241347.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 3.3899331199717215.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 3.3899331199717215.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.898759966443191.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.898759966443191.
# No suppliers found for market for light fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 4/4 [17:31<00:00, 262.96
# Done!
#
# Extracted 1 worksheets in 0.05 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg500-SPS1/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg500-SPS1/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg500-SPS1/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/inventories/remind/SSP2-PkBudg500-SPS1/2050.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/publication.
# Leaving out SE|Electricity|Gas|++|Gas Turbine from Gas ST
# Leaving out SE|Liquids|+|Hydrogen from diesel, synthetic, from electrolysis
# Leaving out SE|Liquids|Fossil|Coal|+|w/o CC from diesel, synthetic, from coal
# Leaving out SE|Liquids|Fossil|Coal|+|w/ CC from diesel, synthetic, from coal, with CCS
# Data package saved at /Users/romain/GitHub/sweet_sure-2050-switzerland/publication/pathways/remind-SSP2-PkBudg500-stem-SPS1.zip

# %%
p.lci

# %%
from pathways import Pathways
p = Pathways(datapackage="image-SSP2-stem-SPS1.zip", debug=True)
# Out:
# Invalid datapackage: Descriptor validation error: {'path': 'mapping/mapping.yaml', 'profile': 'data-resource', 'name': 'mapping', 'format': 'yaml', 'mediatype': 'text/yaml', 'encoding': 'utf-8'} is not valid under any of the given schemas at "resources/33" in descriptor and at "properties/resources/items/oneOf" in profile
# Invalid datapackage: Descriptor validation error: 'data-resource' is not one of ['tabular-data-resource'] at "resources/33/profile" in descriptor and at "properties/resources/items/properties/profile/enum" in profile

# %%
elec = [
        "hydro_run_of_river",
        "hydro (reservoir)",
        "hydro (pumped storage)",
        "nuclear (boiling water)",
        "nuclear (pressure water)",
        "oil (peak devices)",
        "oil (DH CHP)",
        "oil (industry CHP)",
        "gas (CCGT)",
        "gas (OCGT)",
        "gas (CCGT CCS)",
        "gas (CHP DH)",
        "gas (fuel cell DH)",
        "gas (CHP industry)",
        "gas (CHP CCS industry)",
        "gas (CHP fuel cell reformer)",
        "gas (CHP single family)",
        "gas (single family CHP fuel cell)",
        "gas (multi family CHP)",
        "gas (multi family CHP fuel cell)",
        "biogas (services CHP)",
        "gas (services CHP)",
        "gas (services CHP fuel cell)",
        "waste incineration, fossil (CHP)",
        "waste incineration, fossil (industrial)",
        "waste incineration, fossil (CHP, CCS)",
        "waste incineration, fossil (industrial, CCS)",
        "waste incineration, non-fossil (CHP)",
        "waste incineration, non-fossil (industrial)",
        "waste incineration, non-fossil (CHP, CCS)",
        "waste incineration, non-fossil (industrial, CCS)",
        "pv (large scale)",
        "pv (industry)",
        "pv (services)",
        "pv residential (multi family)",
        "pv residential (single family)",
        "wind",
        "geothermal",
        "hydrogen fuel cell (DH CHP)",
        "hydrogen fuel cell (industrial CHP)",
        "hydrogen fuel cell (services CHP)",
        "biomass (DH)",
        "biomass (CHP)",
        "biomass (CCS, BECCS)",
        "biomass (CCS, industrial)",
        "battery (large)",
        "battery (medium)",
        "battery (industry)",
        "battery (services)",
        "battery (single family)",
        "battery (multi family)",
        "CAES",
        "import",
    ]

# %%
import numpy as np
p.calculate(
    methods=[
        #'IPCC 2021 - climate change - GWP 100a, incl. H',
        #'IPCC 2021 - climate change - GWP 100a, incl. H and bio CO2',
        'EF v3.1 EN15804 - climate change - global warming potential (GWP100)',
        'ReCiPe 2016 v1.03, endpoint (I) - total: ecosystem quality - ecosystem quality',
        'EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)',
        'Ecological Scarcity 2021 - total - UBP',
        'ReCiPe 2016 v1.03, endpoint (E) - total: human health - human health',
        'selected LCI results - resource - land occupation',
        'Cumulative Energy Demand (CED) - energy resources: renewable - energy content (HHV)',
        'Cumulative Energy Demand (CED) - energy resources: non-renewable - energy content (HHV)',
    ]  + [m for m in p.lcia_methods if "RELICS" in m],
    regions=["CH",],
    scenarios=[
        "SSP2-RCP26-SPS1",
        #"SSP2-RCP19",
    ],
    variables=[v for v in p.scenarios.coords["variables"].values if v.startswith("FE")],
    years=[
        2020,
        2022,
        2025,
        2030,
        2035,
        2040,
        2045,
        2050
    ],
    multiprocessing=False,
    use_distributions=0,
)
# Out:
# Calculating LCA results for image...
# --- Calculating LCA results for SSP2-RCP26-SPS1...
# ------ Calculating LCA results for 2020...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2022...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2025...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2030...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2035...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2040...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2045...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# ------ Calculating LCA results for 2050...
# 0% [#] 100% | ETA: 00:00:01
# Total time elapsed: 00:00:00
# 0% [########] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:20

# %%
p.lca_results = p.lca_results.sum(dim="act_category")

# %%
arr = p.lca_results.interp(
    year=range(p.lca_results.coords["year"].values.min(), p.lca_results.coords["year"].values.max() + 1)
)

# %%
df = arr.to_dataframe("value")

# %%
df = df[df["value"]!=0.0]
df = df[~df["value"].isnull()]
print(len(df))
df=df.reset_index()
print(df["year"].unique())
# Out:
# 7412401
# [2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2032 2033
#  2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045 2046 2047
#  2048 2049 2050]

# %%
from premise.geomap import Geomap
geo = Geomap("image")

# %%
EU = geo.iam_to_ecoinvent_location("WEU")
EU.remove("CH")
len(EU)
# Out:
# 70

# %%
df.loc[
    df["location"].isin(EU), "location"
] = "EU wo CH"

# %%
df.loc[
    ~df["location"].isin(["CH", "EU wo CH"]), "location"
] = "RoW"

# %% [markdown]
# d = {
#     loc: geo.ecoinvent_to_iam_location(loc)
#     for loc in df["location"].unique()
# }
# df["region from"] = df["location"].map(d)
# df = df.drop('location', axis=1)

# %%
df = df.groupby([
    'variable', 'year', 'region', 'model', 'scenario', 'impact_category', 'location', #"act_category"
]).sum().reset_index()
print(len(df))
# Out:
# 226755

# %%
df["impact_category"] = df["impact_category"].str.replace("RELICS - metals extraction - ", "")
df["impact_category"] = df["impact_category"].str.replace("EF v3.1 - climate change - global warming potential (GWP100)", "climate change")
df["impact_category"] = df["impact_category"].str.replace("EF v3.1 EN15804 - climate change - global warming potential (GWP100)", "climate change")
df["impact_category"] = df["impact_category"].str.replace("selected LCI results - resource - land occupation", "land occupation")
df["impact_category"] = df["impact_category"].str.replace("EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)", "natural resources (minerals and metals)")
df["impact_category"] = df["impact_category"].str.replace("IPCC 2021 - climate change - GWP 100a, incl. H and bio CO2", "climate change")
df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: renewable - energy content (HHV)", "renewable primary energy")
df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: non-renewable - energy content (HHV)", "non-renewable primary energy")
df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (I) - total: ecosystem quality - ecosystem quality", "ecosystem impact")
df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (E) - total: human health - human health", "human health")
df["impact_category"] = df["impact_category"].str.replace("Ecological Scarcity 2021 - total - UBP", "ecological scarcity")

# %%
units = {
    "climate change": "kg CO2-eq.",
    "land occupation": "square meter-year",
    "natural resources (minerals and metals)": "kg Sb-eq.",
    "renewable primary energy": "MJ (HHV)",
    "non-renewable primary energy": "MJ (HHV)",
    "ecosystem impact": "species-year lost",
    "human health": "DALY",
    "ecological scarcity": "UBP pt"
}
df["unit"] = df["impact_category"].map(units)

# %%
df["impact_category"].unique()
# Out:
# array(['non-renewable primary energy', 'renewable primary energy',
#        'natural resources (minerals and metals)', 'climate change',
#        'ecological scarcity', 'Aluminium', 'Antimony', 'Beryllium',
#        'Boron', 'Cadmium', 'Cerium', 'Chromium', 'Cobalt', 'Copper',
#        'Dysprosium', 'Erbium', 'Europium', 'Gadolinium', 'Gallium',
#        'Gold', 'Graphite', 'Hafnium', 'Indium', 'Lanthanum', 'Lead',
#        'Lithium', 'Magnesium', 'Manganese', 'Molybdenum', 'Neodymium',
#        'Nickel', 'Niobium', 'Palladium', 'Platinum', 'Potassium',
#        'Praseodymium', 'Rhenium', 'Rhodium', 'Ruthenium', 'Samarium',
#        'Scandium', 'Selenium', 'Silicon', 'Silver', 'Strontium', 'Sulfur',
#        'Tantalum', 'Tellurium', 'Terbium', 'Tin', 'Titanium', 'Tungsten',
#        'Vanadium', 'Ytterbium', 'Yttrium', 'Zinc', 'Zirconium',
#        'human health', 'ecosystem impact', 'land occupation', 'Iridium'],
#       dtype=object)

# %%
df.head()
# Out:
#         variable  year region  model         scenario  \
# 0  FE_bus_diesel  2020     CH  image  SSP2-RCP26-SPS1
# 1  FE_bus_diesel  2020     CH  image  SSP2-RCP26-SPS1
# 2  FE_bus_diesel  2020     CH  image  SSP2-RCP26-SPS1
# 3  FE_bus_diesel  2020     CH  image  SSP2-RCP26-SPS1
# 4  FE_bus_diesel  2020     CH  image  SSP2-RCP26-SPS1
#
#                 impact_category  location         value      unit
# 0  non-renewable primary energy  EU wo CH  1.718487e+08  MJ (HHV)
# 1  non-renewable primary energy       RoW  8.534095e+08  MJ (HHV)
# 2      renewable primary energy        CH  6.585922e+05  MJ (HHV)
# 3      renewable primary energy  EU wo CH  1.627056e+07  MJ (HHV)
# 4      renewable primary energy       RoW  9.662686e+06  MJ (HHV)

# %%
df.loc[df["unit"].isnull(), "unit"] = "kg"

# %%
from pivottablejs import pivot_ui
from IPython.display import HTML
pivot_ui(df, outfile_path='pivottable_ch.html')
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottable_ch.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pivot = df.pivot_table(index=['variable', 'region', 'model', 'scenario', 'impact_category', 'location', 'unit'], 
                          columns='year', 
                          values='value', 
                          aggfunc='sum').reset_index()
pivot.fillna(0, inplace=True)

# %%
scenarios = p.scenarios.sel(region="CH", pathway='SSP2-RCP26-SPS1', model="image").astype(float).interp(
    year=range(p.scenarios.coords["year"].values.min(), p.scenarios.coords["year"].values.max() + 1)
)

# %%
df_scenarios = scenarios.to_dataframe("value").reset_index().pivot_table(
    index=['variables', 'region', 'model', 'pathway', ], 
                          columns='year', 
                          values='value', 
                          aggfunc='sum'
)

# %%
df_scenarios["unit"] = "PJ"
df_scenarios["impact_category"] = "Production"

# %%
df_scenarios = df_scenarios.reset_index()

# %%
df_scenarios.rename(columns={'variables':'variable'}, inplace=True)
df_scenarios.rename(columns={'pathway':'scenario'}, inplace=True)

# %%
import pandas as pd
df_final = pd.concat([pivot, df_scenarios], ignore_index=True)

# %%
df_final.loc[df_final["location"].isnull(), "location"] = "CH"

# %%
df_final.to_excel("indicators_export_SPS1.xlsx")

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /Users/romain/anaconda3/envs/pathways/lib/python3.11/site-packages (6.0.1)

# %%
# Adjusting the YAML loader to handle Python-specific objects (tuples)
import yaml
from yaml import SafeLoader
from yaml.constructor import SafeConstructor

# Define a constructor for Python tuples
def construct_python_tuple(loader, node):
    return tuple(loader.construct_sequence(node))

# Add the constructor to the SafeLoader
SafeLoader.add_constructor('tag:yaml.org,2002:python/tuple', construct_python_tuple)

file_path = "/Users/romain/Github/pathways/pathways/data/activities_classifications.yaml"

# Now, let's try loading the YAML file again with the adjusted loader
with open(file_path, 'r') as file:
    data_adjusted = yaml.load(file, Loader=SafeLoader)

# Display the first few items to understand its structure with adjustments
list(data_adjusted.items())[:5]
# Out:
# [(('1,1-difluoroethane production, HFC-152a',
#    '1,1-difluoroethane, HFC-152a',
#    'kilogram',
#    'RoW'),
#   'Manufacture of basic chemicals'),
#  (('1,1-difluoroethane production, HFC-152a',
#    '1,1-difluoroethane, HFC-152a',
#    'kilogram',
#    'US'),
#   'Manufacture of basic chemicals'),
#  (('1,1-dimethylcyclopentane to generic market for solvent, organic',
#    'solvent, organic',
#    'kilogram',
#    'GLO'),
#   'Manufacture of chemicals and chemical products'),
#  (('1-methoxy-2-propanol production',
#    '1-methoxy-2-propanol',
#    'kilogram',
#    'GLO'),
#   'Manufacture of basic chemicals'),
#  (('1-methylcyclopropene production',
#    '1-methylcyclopropene',
#    'kilogram',
#    'GLO'),
#   'Manufacture of basic chemicals')]

# %%
# Modify the data by removing the last item from each tuple key
modified_data = {(key[:-1]): value for key, value in data_adjusted.items()}

# Define the new file path for the modified YAML
modified_file_path = 'modified_activities_classifications.yaml'

# Re-export the modified data to a new YAML file
with open(modified_file_path, 'w') as modified_file:
    yaml.dump(modified_data, modified_file)
