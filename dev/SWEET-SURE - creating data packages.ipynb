# %%
from premise import *
import bw2data
from datapackage import Package
bw2data.projects.set_current("ecoinvent-3.10-cutoff")

# %%
clear_inventory_cache()
# Out:
# Inventory cache cleared!

# %%
#clear_inventory_cache()
sps = Package("../datapackage.json")
scenarios=[
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS1", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS2", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS3", "data": sps}]},
    {"model": "remind", "pathway": "SSP2-PkBudg1150", "external scenarios": [{"scenario": "SPS4", "data": sps}]},
]

for scenario in scenarios:
    name=f"{scenario['model']}-{scenario['pathway']}-stem-{scenario['external scenarios'][0]['scenario']}"
    print(name)
    ndb = PathwaysDataPackage(
        scenarios=[
            scenario,
        ],
        years=[
            2020,
            2024,
            2030,
            2040,
            2050
        ],
        source_db="ecoinvent-3.10.1-cutoff", # <-- name of the database in the BW2 project. Must be a string.
        source_version="3.10", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
        key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
        use_absolute_efficiency=True,
        biosphere_name="biosphere3"
    )
    
    ndb.create_datapackage(
        name=name,
        #transformations=["electricity", ],
        contributors=[
            {"name": "Romain",
            "email": "r_s at me.com",}
        ],
    )
# Out:
# remind-SSP2-PkBudg1150-stem-SPS1
# premise v.(2, 3, 0, 'dev0')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Done!
# Processing scenarios for all sectors:   0%|     | 0/5 [00:00<?, ?it/s]
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702071940311185.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702071940311185.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7731864746280066.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7731864746280066.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442164493757413.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442164493757413.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1923527055804946.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1923527055804946.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5021142827522795.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5021142827522795.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2519028544770516.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2519028544770516.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.514148715972071.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.514148715972071.
# Processing scenarios for all sectors:  20%|▏| 1/5 [02:37<10:28, 157.09
# Warning: No activities found for Gas ST -- revise mapping.
# ---> MAJOR anomalies found during steel update: check the change report.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.6159696686373939.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.6159696686373939.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702216149672689.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702216149672689.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773199453470542.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773199453470542.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442277522716432.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442277522716432.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.216933786584257.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.216933786584257.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.521380535430904.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.521380535430904.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2692424818878134.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2692424818878134.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.5559183357230248.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.5559183357230248.
# Processing scenarios for all sectors:  40%|▍| 2/5 [05:35<08:29, 169.71
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619704.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7732015492957733.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647874.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.239075733668822.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.239075733668822.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5387350344971846.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5387350344971846.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2848615310474663.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2848615310474663.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.6185727653494557.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.6185727653494557.
# Processing scenarios for all sectors:  60%|▌| 3/5 [08:46<05:58, 179.28
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.550658000496504.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.550658000496504.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.782948162551314.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.782948162551314.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.5046533462961826.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.5046533462961826.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8585878320272133.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.72299681472684.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 1.72299681472684.
# Processing scenarios for all sectors:  80%|▊| 4/5 [11:55<03:03, 183.15
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.08 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.2586402871849414.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.2586402871849414.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.5433487522935538.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.5433487522935538.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9704061309757348.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9704061309757348.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7733655178781613.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.7733655178781613.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5443723729269272.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5443723729269272.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.943516068364797.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.943516068364797.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 3.090863945475111.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 3.090863945475111.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.7817775509276.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.7817775509276.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.859958891066578.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.859958891066578.
# No suppliers found for market for light fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for kerosene (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 5/5 [14:57<00:00, 179.53
# Done!
#
# Extracted 1 worksheets in 0.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.05 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# True
# True
# True
# True
# True
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS1/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS1/2024.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS1/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS1/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS1/2050.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev.
# Leaving out SE|Electricity|Gas|++|Gas Turbine from Gas ST
# Leaving out SE|Liquids|+|Hydrogen from diesel, synthetic, from electrolysis
# Leaving out SE|Liquids|Fossil|Coal|+|w/o CC from diesel, synthetic, from coal
# Leaving out SE|Liquids|Fossil|Coal|+|w/ CC from diesel, synthetic, from coal, with CCS
# Data package saved at /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/remind-SSP2-PkBudg1150-stem-SPS1.zip
# remind-SSP2-PkBudg1150-stem-SPS2
# premise v.(2, 3, 0, 'dev0')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# ...
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2244383754875354.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.2244383754875354.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5272625105172573.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.5272625105172573.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2745362594655316.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.2745362594655316.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3268867924528302and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3268867924528302and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.55and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.55and expected efficiency is 0.0.
# Processing scenarios for all sectors:  80%|▊| 4/5 [20:29<04:35, 275.03
# Warning: No activities found for Gas ST -- revise mapping.
# Warning: No activities found for CON_LOSSHF -- revise mapping.
# Warning: No activities found for PP_ENGGAS -- revise mapping.
# Warning: No activities found for PP_MOD_CCSBIOG -- revise mapping.
# Warning: No activities found for PP_MOD_CCSHC1 -- revise mapping.
# Warning: No activities found for TRA_OT_AIRGSL -- revise mapping.
# Extracted 1 worksheets in 0.07 seconds
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Stopping: Efficiency factor for heat and power co-generation, natural gas, 1MW electrical, lean burn_gas (CHP fuel cell reformer) in CH is 0.4942796098638653and expected efficiency is 0.0.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.50127115161841.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 160kW e in CH is 1.50127115161841.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 1.9702239436619735.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, at co-generation plastic w in CH is 1.773201549295776.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 1.5442295774647898.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1890370426427896.
# Warning: Efficiency factor for electricity production, from incineration of plast in CH is 3.1890370426427896.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.499515519909213.
# Warning: Efficiency factor for electricity production, from biowaste, municipal i in CH is 2.499515519909213.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.249563967918292.
# Warning: Efficiency factor for electricity production, at co-generation biowaste- in CH is 2.249563967918292.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at co-generation natural gas-fired power plant, post, pipeline 200km, storage 1000m in CH is 0.9259259259259258and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3466981132075472and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m in CH is 0.3466981132075472and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.56and expected efficiency is 0.0.
# Stopping: Efficiency factor for electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m in CH is 0.56and expected efficiency is 0.0.
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 5/5 [27:35<00:00, 331.14
# Done!
#
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.04 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# True
# True
# True
# True
# True
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2024.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways/inventories/remind/SSP2-PkBudg1150-SPS4/2050.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev.
# Leaving out SE|Electricity|Gas|++|Gas Turbine from Gas ST
# Leaving out SE|Liquids|+|Hydrogen from diesel, synthetic, from electrolysis
# Leaving out SE|Liquids|Fossil|Coal|+|w/o CC from diesel, synthetic, from coal
# Leaving out SE|Liquids|Fossil|Coal|+|w/ CC from diesel, synthetic, from coal, with CCS
# Data package saved at /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/remind-SSP2-PkBudg1150-stem-SPS4.zip
