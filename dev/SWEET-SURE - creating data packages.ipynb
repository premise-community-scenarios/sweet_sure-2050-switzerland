# %%
from premise import *
import bw2data
from datapackage import Package
bw2data.projects.set_current("ecoinvent-3.11-cutoff-bw25")

from premise import PathwaysDataPackage
#clear_inventory_cache()
sps = Package("../datapackage.json")

STEM_scenarios = {
    #"SPS1":"SPS1_bas0",
    #"SPS2":"SPS2_bas0",
    #"SPS3":"SPS3_bas0",
    #"SPS4":"SPS4_bas0",
    #"SPS1_FIN_Low":"SPS1_fin1",
    #"SPS1_FIN_Mid":"SPS1_fin2",
    #"SPS1_FIN_High":"SPS1_fin3",
    #"SPS2_FIN_Low":"SPS2_fin1",
    #"SPS2_FIN_Mid":"SPS2_fin2",
    #"SPS2_FIN_High":"SPS2_fin3",
    #"SPS3_FIN_Low":"SPS3_fin1",
    #"SPS3_FIN_Mid":"SPS3_fin2",
    #"SPS3_FIN_High":"SPS3_fin3",
    #"SPS4_FIN_Low":"SPS4_fin1",
    #"SPS4_FIN_Mid":"SPS4_fin2",
    #"SPS4_FIN_High":"SPS4_fin3",
    #"SPS1_SOC_Low":"SPS1_soc1",
    #"SPS1_SOC_Mid":"SPS1_soc2",
    #"SPS1_SOC_High":"SPS1_soc3",
    #"SPS2_SOC_Low":"SPS2_soc1",
    #"SPS2_SOC_Mid":"SPS2_soc2",
    #"SPS2_SOC_High":"SPS2_soc3",
    #"SPS3_SOC_Low":"SPS3_soc1",
    #"SPS3_SOC_Mid":"SPS3_soc2",
    #"SPS3_SOC_High":"SPS3_soc3",
    #"SPS4_SOC_Low":"SPS4_soc1",
    #"SPS4_SOC_Mid":"SPS4_soc2",
    #"SPS4_SOC_High":"SPS4_soc3",
    #"SPS1_NUC_Low":"SPS1_nuc1",
    #"SPS1_NUC_Mid":"SPS1_nuc2",
    "SPS1_NUC_High":"SPS1_nuc3",
    "SPS2_NUC_Low":"SPS2_nuc1",
    "SPS2_NUC_Mid":"SPS2_nuc2",
    "SPS2_NUC_High":"SPS2_nuc3",
    "SPS3_NUC_Low":"SPS3_nuc1",
    "SPS3_NUC_Mid":"SPS3_nuc2",
    "SPS3_NUC_High":"SPS3_nuc3",
    "SPS4_NUC_Low":"SPS4_nuc1",
    "SPS4_NUC_Mid":"SPS4_nuc2",
    "SPS4_NUC_High":"SPS4_nuc3",
}

scenarios=[
    {"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": stem_scenario, "data": sps}]}
    for stem_scenario in STEM_scenarios.values()
]

for scenario in scenarios:
    name=f"{scenario['model']}-{scenario['pathway']}-stem-{scenario['external scenarios'][0]['scenario']}"
    print(name)
    ndb = PathwaysDataPackage(
        scenarios=[
            scenario,
        ],
        years=[
            2020,
            2025,
            2030,
            2035,
            2040,
            2045,
            2050
        ],
        source_db="ecoinvent-3.11-cutoff",
        source_version="3.11",
        key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
        use_absolute_efficiency=True,
        biosphere_name="ecoinvent-3.11-biosphere"
    )
    
    ndb.create_datapackage(
        name=name,
        contributors=[
            {"name": "Romain",
            "email": "r_s at me.com",}
        ],
    )
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# 14:14:31+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# remind-SSP2-PkBudg1000-stem-SPS1_nuc3
# premise v.(2, 3, 9)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|█████████████████████████████████| 25413/25413 [00:00<00:00, 319175.24it/s]
# Adding exchange data to activities
# 100%|████████████████████████████████| 855046/855046 [00:44<00:00, 19090.77it/s]
# Filling out exchange data
# 100%|███████████████████████████████████| 25413/25413 [00:04<00:00, 5952.48it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-Carma-CCS.xlsx
# Extracted 1 worksheets in 0.13 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-co-firing-power-plants.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-combined-heat-power-plant-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-carbon-capture.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-biogas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-waste-CHP.xlsx
# Extracted 4 worksheets in 0.19 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-carbon-fiber.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-lithium.xlsx
# Extracted 7 worksheets in 0.03 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-cobalt.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-NMC955-LTO.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------------------------+
# |              Name              |       Reference product        | Location |              File             |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# | market for battery management  | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# | battery management system prod | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-LiS.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-LiO2.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-vanadium.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------------+
# |              Name              |       Reference product        | Location |             File            |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# | market for styrene butadiene r | styrene butadiene rubber (SBR) |   RER    | lci-batteries-vanadium.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-vanadium-redox-flow.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-organic-and-hybrid-redox-flow.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-batteries-SIB.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-battery-capacity.xlsx
# Extracted 2 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-home-batteries.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-heat-pump-high-temp.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PV.xlsx
# Extracted 2 worksheets in 1.43 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | 1,1-difluoroethane production  |       1,1-difluoroethane       |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |   multi-Si wafer production    |         multi-Si wafer         |   RER    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, multi-S |   RER    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, single- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, multi-Si w |   RER    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, single-Si  |   RER    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaics, electric instal | photovoltaics, electric instal |    CH    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, multi-Si,  |   silicon, multi-Si, casted    |   RER    | lci-PV.xlsx |
# | silicon production, single cry | silicon, single crystal, Czoch |   RER    | lci-PV.xlsx |
# | silicon production, solar grad |      silicon, solar grade      |   RER    | lci-PV.xlsx |
# | single-Si wafer production, ph | single-Si wafer, photovoltaic  |   RER    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PGM.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-electrolysis.xlsx
# Extracted 1 worksheets in 0.06 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-thermochemical-water-splitting.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-pyrolysis.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-cement-plant.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-coal-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, coal gasi | hydrogen, gaseous, low pressur |   RoW    | lci-hydrogen-coal-gasification |
# | methanol production, from coal |            methanol            |   RoW    | lci-hydrogen-coal-gasification |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-coal-gasification_CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal-with-CCS.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-distribution.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-smr-atr-biogas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-smr-atr-natgas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, steam met | hydrogen, gaseous, low pressur |   RER    | lci-hydrogen-smr-atr-natgas.xl |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-wood-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-oil.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-turbine.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-syngas.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-methanol-from-wood.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-ammonia.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-syngas-from-coal.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-biofuels.xlsx
# Extracted 5 worksheets in 0.15 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-natural-gas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-geothermal.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-BIGCC.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-nuclear_EPR.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-nuclear_SMR.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-wave_energy.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-fuel_cell.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-concentrating-solar-power.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-hydrogen-heating.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-methanol-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-electric-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-germanium.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Sodium I', 'natural resource', 'in ground', 'kilogram') in lci-germanium.xlsx. Flow ignored.
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-rhenium.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-two_wheelers.xlsx
# Extracted 19 worksheets in 0.33 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-trucks.xlsx
# Extracted 1 worksheets in 0.13 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-buses.xlsx
# Extracted 1 worksheets in 0.18 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+----------------+
# |              Name              |       Reference product        | Location |      File      |
# +--------------------------------+--------------------------------+----------+----------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-buses.xlsx |
# +--------------------------------+--------------------------------+----------+----------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-pass_cars.xlsx
# Extracted 1 worksheets in 1.83 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +-----------------+-------------------+----------+--------------------+
# |       Name      | Reference product | Location |        File        |
# +-----------------+-------------------+----------+--------------------+
# | HDPE tank liner |  HDPE tank liner  |   RER    | lci-pass_cars.xlsx |
# +-----------------+-------------------+----------+--------------------+
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-rail-freight.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PV-GaAs.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PV-perovskite.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-biochar-spruce.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-ocean-liming.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/romain/GitHub/premise/premise/data/additional_inventories/lci-coastal-enhanced-weathering.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# ...
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Processing scenarios for all sectors:  71%|▋| 5/7 [12:07<04:50, 145.49
# Importing /Users/romain/GitHub/sweet_sure-2050-switzerland/inventories/lci-sweet_sure.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Processing scenarios for all sectors:  86%|▊| 6/7 [14:35<02:26, 146.35
# Importing /Users/romain/GitHub/sweet_sure-2050-switzerland/inventories/lci-sweet_sure.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.10 → 3.11
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 7/7 [17:15<00:00, 147.96
# Done!
#
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2020.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2025.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2030.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2035.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2040.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2045.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/inventories/remind/SSP2-PkBudg1000-SPS4_nuc3/2050.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/export/change reports/.
# Missing classifications for 2 unique activities (TSV, also saved to /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/pathways_temp/classifications/missing_classifications.tsv):
# name	reference product
# market for heavy fuel oil (SPS)	heavy fuel oil
# market for light fuel oil (SPS)	light fuel oil
# Data package saved at /Users/romain/GitHub/sweet_sure-2050-switzerland/dev/remind-SSP2-PkBudg1000-stem-SPS4_nuc3.zip

# %%
#clear_inventory_cache()
sps = Package("../datapackage.json")
scenarios=[
    {"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2025},
    #{"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2030},
    {"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2035},
    #{"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2040},
    #{"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2045},
    {"model": "remind", "pathway": "SSP2-PkBudg1000", "external scenarios": [{"scenario": "SPS1", "data": sps}], "year": 2050},
]

ndb = NewDatabase(
    scenarios=scenarios,
    source_db="ecoinvent-3.11-cutoff",
    source_version="3.11",
    key="tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=",
    use_absolute_efficiency=True,
    biosphere_name="biosphere3"
)

ndb.update()
# Out:
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|█████████████████████████████████| 25412/25412 [00:00<00:00, 166104.32it/s]
# Adding exchange data to activities
# 100%|████████████████████████████████| 855034/855034 [00:19<00:00, 43482.96it/s]
# Filling out exchange data
# 100%|██████████████████████████████████| 25412/25412 [00:00<00:00, 26233.01it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Extracted 1 worksheets in 0.07 seconds
# Migrating from 3.5 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.5 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.5 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# WARNING: missing classification for carbon dioxide, captured and stored, by afforestation | carbon dioxide, captured
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.6 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 4 worksheets in 0.13 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 7 worksheets in 0.02 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------------------------+
# |              Name              |       Reference product        | Location |              File             |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# | market for battery management  | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# | battery management system prod | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------------+
# |              Name              |       Reference product        | Location |             File            |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# | market for styrene butadiene r | styrene butadiene rubber (SBR) |   RER    | lci-batteries-vanadium.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.03 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 2 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Extracted 1 worksheets in 0.23 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |   multi-Si wafer production    |         multi-Si wafer         |   RER    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, multi-S |   RER    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, single- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, multi-Si w |   RER    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, single-Si  |   RER    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, multi-Si,  |   silicon, multi-Si, casted    |   RER    | lci-PV.xlsx |
# | silicon production, single cry | silicon, single crystal, Czoch |   RER    | lci-PV.xlsx |
# | silicon production, solar grad |      silicon, solar grade      |   RER    | lci-PV.xlsx |
# | single-Si wafer production, ph | single-Si wafer, photovoltaic  |   RER    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.04 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, coal gasi | hydrogen, gaseous, low pressur |   RoW    | lci-hydrogen-coal-gasification |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, steam met | hydrogen, gaseous, low pressur |   RER    | lci-hydrogen-smr-atr-natgas.xl |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 5 worksheets in 0.11 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.04 seconds
# Migrating from 3.6 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.06 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.12 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 19 worksheets in 0.23 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.09 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.12 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+----------------+
# |              Name              |       Reference product        | Location |      File      |
# +--------------------------------+--------------------------------+----------+----------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-buses.xlsx |
# +--------------------------------+--------------------------------+----------+----------------+
# Extracted 1 worksheets in 0.76 seconds
# Migrating from 3.7 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +-----------------+-------------------+----------+--------------------+
# |       Name      | Reference product | Location |        File        |
# +-----------------+-------------------+----------+--------------------+
# | HDPE tank liner |  HDPE tank liner  |   RER    | lci-pass_cars.xlsx |
# +-----------------+-------------------+----------+--------------------+
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.02 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.00 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.09 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------+
# |              Name              |       Reference product        | Location |          File         |
# +--------------------------------+--------------------------------+----------+-----------------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-final-energy.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------+
# Extracted 3 worksheets in 0.01 seconds
# Migrating from 3.8 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 1 worksheets in 0.01 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Extracted 8 worksheets in 0.05 seconds
# Migrating from 3.9 to 3.10 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# - Fetching IAM data
# Found file: remind_SSP2-PkBudg1000
# Reading remind_SSP2-PkBudg1000 as CSV file
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# Found file: remind_SSP2-PkBudg1000
# Reading remind_SSP2-PkBudg1000 as CSV file
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# Found file: remind_SSP2-PkBudg1000
# Reading remind_SSP2-PkBudg1000 as CSV file
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/romain/Github/premise/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |   PE|Production|Biomass|Lignocellulosic|+|Residues   |
# | PE|Production|Biomass|Lignocellulosic|+|Energy Crops |
# +------------------------------------------------------+
# Done!
# Processing scenarios for all sectors:   0%|     | 0/3 [00:00<?, ?it/s]
# No biomass scenario data available -- skipping
# Extracted 1 worksheets in 0.06 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Warning: Efficiency factor for electricity production, natural gas, 10MW in CH is 1.7258583440084805.
# Warning: Efficiency factor for electricity production, natural gas, 10MW in CH is 1.7258583440084805.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.0850479336155865.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.0850479336155865.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.114351839353397.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.114351839353397.
# Processing scenarios for all sectors:  33%|▎| 1/3 [01:20<02:41, 80.99s
# No biomass scenario data available -- skipping
# Extracted 1 worksheets in 0.06 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Warning: Efficiency factor for electricity production, natural gas, 10MW in CH is 1.7258583440084805.
# Warning: Efficiency factor for electricity production, natural gas, 10MW in CH is 1.7258583440084805.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.0850479336155865.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 3.0850479336155865.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.114351839353397.
# Warning: Efficiency factor for electricity production, at biomass-fired IGCC powe in CH is 2.114351839353397.
# Processing scenarios for all sectors:  67%|▋| 2/3 [02:45<01:23, 83.30s
# No biomass scenario data available -- skipping
# Extracted 1 worksheets in 0.06 seconds
# Migrating from 3.10 to 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+---------------------+
# |              Name              |       Reference product        | Location |         File        |
# +--------------------------------+--------------------------------+----------+---------------------+
# |     charging station, 3kW      |     charging station, 3kW      |   GLO    | lci-sweet_sure.xlsx |
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-sweet_sure.xlsx |
# +--------------------------------+--------------------------------+----------+---------------------+
# The following datasets will be duplicated:
# +----------------------------------------------------+----------------------------------------------------+
# |                        Name                        |                 Reference product                  |
# +----------------------------------------------------+----------------------------------------------------+
# | heat and power co-generation, natural gas, 1MW ele |             electricity, high voltage              |
# | heat and power co-generation, natural gas, 160kW e |              electricity, low voltage              |
# | electricity production, from incineration of plast | electricity, from incineration of plastic waste mi |
# | electricity production, at co-generation plastic w | electricity, from plastic waste mixture, municipal |
# | electricity production, from biowaste, municipal i | electricity, from biowaste, municipal incineration |
# | electricity production, at co-generation biowaste- | electricity, from biowaste, municipal incineration |
# |  electricity production, from photovoltaic panels  |              electricity, low voltage              |
# |  electricity production, from hydrogen fuel cell   |              electricity, low voltage              |
# | electricity supply, from stationary battery (CONT  |              electricity, low voltage              |
# |         heat and power co-generation, oil          |             electricity, high voltage              |
# |             market for forest residue              |                   forest residue                   |
# |            ethanol production from wood            | ethanol, without water, in 95% solution state, fro |
# | hydrogen production, gaseous, 30 bar, from PEM ele |             hydrogen, gaseous, 30 bar              |
# |  electricity, used in industrial electric boiler   |              electricity, low voltage              |
# |     electricity, used in industrial heat pump      |              electricity, low voltage              |
# | electricity, used in industrial electric processes |              electricity, low voltage              |
# |  light fuel oil, burned in industrial furnace 1MW  |                        heat                        |
# |  natural gas, burned in industrial furnace >100kW  |                        heat                        |
# | heat production, biomethane, at boiler condensing  |      heat, central or small-scale, biomethane      |
# |    heat, from on-site industrial gas-fired CHP     |                        heat                        |
# |    heat, from on-site industrial fuel cell CHP     |                        heat                        |
# |    heat, from on-site industrial wood-fired CHP    |                        heat                        |
# |  heat, from on-site industrial hydrogen-fired CHP  |                        heat                        |
# |   wood, burned in wood industrial furnace 1-10MW   |                        heat                        |
# | pellet, burned in pellet industrial furnace 300kW  |                        heat                        |
# |    solar energy, from industrial hot water tank    |                        heat                        |
# |        hydrogen burned, in hydrogen boiler         |                        heat                        |
# |  electricity, used in residential electric boiler  |              electricity, low voltage              |
# |     electricity, used in residential heat pump     |              electricity, low voltage              |
# | light fuel oil, burned in residential 10kW boiler  |                        heat                        |
# | natural gas, burned in residential natural gas boi |                        heat                        |
# | hard coal, burned in hard coal residential boiler  |                        heat                        |
# |   wood, burned in residential wood stove 5-15kW    |                        heat                        |
# | pellet, burned in residential pellet stove 5-15kW  |                        heat                        |
# |   solar energy, from residential hot water tank    |                        heat                        |
# |     electricity, used in passenger car vehicle     |              electricity, low voltage              |
# |      hydrogen, used in passenger car vehicle       |                        heat                        |
# |      petrol, burned in passenger car vehicle       |                        heat                        |
# |      diesel, burned in passenger car vehicle       |                        heat                        |
# |  compressed gas, burned in passenger car vehicle   |                        heat                        |
# | electricity, used in single deck coach or urban bu |              electricity, low voltage              |
# |  hydrogen, used in single deck coach or urban bus  |                        heat                        |
# |  diesel, burned in single deck coach or urban bus  |                        heat                        |
# | compressed gas, burned in single deck coach or urb |                        heat                        |
# +----------------------------------------------------+----------------------------------------------------+
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.259970496007111.
# Warning: Efficiency factor for heat and power co-generation, natural gas, 1MW ele in CH is 2.259970496007111.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8610106135388658.
# Warning: Efficiency factor for electricity production, at co-generation natural g in CH is 2.8610106135388658.
# No suppliers found for market for light fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for heavy fuel oil (SPS) in CH. No market created. This may cause linking issue.
# No suppliers found for market for kerosene (SPS) in CH. No market created. This may cause linking issue.
# Processing scenarios for all sectors: 100%|█| 3/3 [04:18<00:00, 86.12s
# Done!

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:23
# Title: Writing activities to SQLite3 database:
#   Started: 11/17/2025 13:20:18
#   Finished: 11/17/2025 13:20:42
#   Total time elapsed: 00:00:23
#   CPU %: 92.90
#   Memory %: 15.47
# Created database: ei_cutoff_3.11_remind_SSP2-PkBudg1000_2025_SPS1 2025-11-17
# Running all checks...
# Minor anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:23
# Title: Writing activities to SQLite3 database:
#   Started: 11/17/2025 13:25:17
#   Finished: 11/17/2025 13:25:41
#   Total time elapsed: 00:00:23
#   CPU %: 91.90
#   Memory %: 16.47
# Created database: ei_cutoff_3.11_remind_SSP2-PkBudg1000_2035_SPS1 2025-11-17
# Running all checks...
# Minor anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:23
# Title: Writing activities to SQLite3 database:
#   Started: 11/17/2025 13:30:25
#   Finished: 11/17/2025 13:30:48
#   Total time elapsed: 00:00:23
#   CPU %: 92.70
#   Memory %: 16.22
# Created database: ei_cutoff_3.11_remind_SSP2-PkBudg1000_2050_SPS1 2025-11-17
# Generate scenario report.
# Report saved under /Users/romain/Github/sweet_sure-2050-switzerland/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/Github/sweet_sure-2050-switzerland/dev/export/change reports/.

# %%
dbs = [
    "ei_cutoff_3.11_remind_SSP2-PkBudg1000_2025_SPS1 2025-11-17",
    "ei_cutoff_3.11_remind_SSP2-PkBudg1000_2035_SPS1 2025-11-17",
    "ei_cutoff_3.11_remind_SSP2-PkBudg1000_2050_SPS1 2025-11-17",
]

# %%
acts = {
    "Solar PV, rooftop": "electricity production, photovoltaic, at 93 kWp slanted-roof, single-Si, panel, mounted",
    "Solar PV, open-ground": "electricity production, photovoltaic, at 560 kWp open ground, single-Si",
    "Wind": "electricity production, wind, 1-3MW turbine, onshore",
    #"Run-of-River Hydropower": "electricity production, hydro, run-of-river",
    #"Reservoir Hydropower": "electricity production, hydro, reservoir, alpine region",
    "Natural Gas Turbine with CSS": "electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m",
    "Natural Gas Turbine without CCS": "electricity production, natural gas, combined cycle power plant",
    "Biomethane Turbine without CCS": "electricity production, biomethane, combined cycle power plant",
    #"Fuel Oil Generation": "electricity production, oil",
    #"Biomass with CCS": "electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m",
    #"Biomass without CCS": "electricity production, at biomass-fired IGCC power plant",
    #"Lithium-Ion Batteries": "market for battery capacity (MIX scenario)",
    #"Pumped Hydropower Storage": "electricity production, hydro, pumped storage",
    #"Geothermal": "electricity production, deep geothermal",
    "Nuclear": "electricity production, nuclear, pressure water reactor",
    "Hydrogen Turbine": "electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing",
    #"Electricity Imports": "electricity import, from neighboring countries",
    "Hydrogen, from solar photovoltaic": "",
    "Battery, Li-ion NMC": "market for battery capacity, Li-ion, NMC811, stationary",
    "Battery, Li-ion LFP": "market for battery capacity, Li-ion, LFP, stationary",
    "Battery, Li-ion Si": "market for battery capacity, Sodium-ion, SiB, stationary", 

    "Solar PV plant, rooftop, 1 MW": "photovoltaic slanted-roof installation, 93 kWp, single-Si, panel, mounted, on roof",
    "Solar PV, open-ground plant, 1 MW": "photovoltaic open ground installation, 560 kWp, single-Si, on open ground",
    "Wind plant, 1 MW": "market for wind turbine, 2MW, onshore",
    "Natural Gas Turbine with CSS plant, 1 MW": "market for gas power plant, combined cycle, 400MW electrical",
    "Natural Gas Turbine without CCS plant, 1 MW": "market for gas power plant, combined cycle, 400MW electrical",
    "Biomethane Turbine without CCS plant, 1 MW": "market for gas power plant, combined cycle, 400MW electrical",
    "Nuclear plant, 1 MW": "nuclear power plant construction, pressure water reactor, 1000MW",
    "Hydrogen Turbine plant, 1 MW": "gas power plant construction, combined cycle, 400MW electrical",

}


acts_rev = {v: k for k, v in acts.items()}

# %%
res = {
    db.replace("ei_cutoff_3.11_", "").split(" ")[0]: {
        v: None for v in acts.keys()
    }
    for db in dbs
}

# %%
for db in dbs:
    name = db.replace("ei_cutoff_3.11_", "").split(" ")[0]
    for act in bw2data.Database(db):
        if act["name"] in acts_rev:
            if act["location"] == "CH" and act["unit"] == "kilowatt hour":
                if res[name][acts_rev[act["name"]]] is None:
                    res[name][acts_rev[act["name"]]] = {"dataset": act}

for db in dbs:
    name = db.replace("ei_cutoff_3.11_", "").split(" ")[0]
    for act in bw2data.Database(db):
        if act["name"] in acts_rev:
            if act["location"] in ["EUR", "RER"] and act["unit"] in ("kilowatt hour", "kilogram"):
                if res[name][acts_rev[act["name"]]] is None:
                    res[name][acts_rev[act["name"]]] = {"dataset": act}

for db in dbs:
    name = db.replace("ei_cutoff_3.11_", "").split(" ")[0]
    for act in bw2data.Database(db):
        if act["name"] in acts_rev:
            if act["location"] in ["GLO",] and act["unit"] == "kilowatt hour":
                if res[name][acts_rev[act["name"]]] is None:
                    res[name][acts_rev[act["name"]]] = {"dataset": act}

# %%
res
# Out:
# {'remind_SSP2-PkBudg1000_2025_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}},
#  'remind_SSP2-PkBudg1000_2030_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}},
#  'remind_SSP2-PkBudg1000_2035_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}},
#  'remind_SSP2-PkBudg1000_2040_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}},
#  'remind_SSP2-PkBudg1000_2045_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}},
#  'remind_SSP2-PkBudg1000_2050_SPS1': {'Solar PV': {'dataset': 'electricity production, photovoltaic, residential' (kilowatt hour, CH, None)},
#   'Wind': {'dataset': 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine with CSS': {'dataset': 'electricity production, at natural gas-fired combined cycle power plant, post, pipeline 200km, storage 1000m' (kilowatt hour, CH, None)},
#   'Natural Gas Turbine without CCS': {'dataset': 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CH, None)},
#   'Nuclear': {'dataset': 'electricity production, nuclear, pressure water reactor' (kilowatt hour, CH, None)},
#   'Hydrogen Turbine': {'dataset': 'electricity production, from hydrogen-fired one gigawatt gas turbine, for grid balancing' (kilowatt hour, CH, None)},
#   'Hydrogen, from onshore wind power': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from onshore wind electricity' (kilogram, RER, None)},
#   'Hydrogen, from solar photovoltaic': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from rooftop solar photovoltaic electricity' (kilogram, RER, None)},
#   'Hydrogen, from hydropower': {'dataset': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from hydropower electricity' (kilogram, RER, None)},
#   'Battery, Li-ion NMC': {'dataset': 'market for battery capacity, Li-ion, NMC811, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion LFP': {'dataset': 'market for battery capacity, Li-ion, LFP, stationary' (kilowatt hour, GLO, None)},
#   'Battery, Li-ion Si': {'dataset': 'market for battery capacity, Sodium-ion, SiB, stationary' (kilowatt hour, GLO, None)}}}

# %%
methods = [
    ('IPCC 2021 (incl. biogenic CO2)', 'climate change: total (incl. biogenic CO2, incl. SLCFs)', 'global warming potential (GWP100)'),
    ('Inventory results and indicators', 'resources', 'land occupation'),
    ('ReCiPe 2016 v1.03, endpoint (H)', 'total: ecosystem quality', 'ecosystem quality'),
    ('Inventory results and indicators', 'waste disposal', 'total volume of radioactive waste'),
    ('Inventory results and indicators', 'waste disposal', 'total mass for underground deposits')
]

# %%
[m for m in bw2data.methods if "GWP" in str(m)]
# Out:
# [('CML v4.8 2016 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('CML v4.8 2016', 'climate change', 'global warming potential (GWP100)'),
#  ('Ecological Scarcity 2021 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('Ecological Scarcity 2021',
#   'climate change',
#   'global warming potential (GWP100)'),
#  ('EF v3.0 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.0 no LT',
#   'climate change: biogenic no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.0 no LT',
#   'climate change: fossil no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.0 no LT',
#   'climate change: land use and land use change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.0', 'climate change', 'global warming potential (GWP100)'),
#  ('EF v3.0', 'climate change: biogenic', 'global warming potential (GWP100)'),
#  ('EF v3.0', 'climate change: fossil', 'global warming potential (GWP100)'),
#  ('EF v3.0',
#   'climate change: land use and land use change',
#   'global warming potential (GWP100)'),
#  ('EF v3.1 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.1 no LT',
#   'climate change: biogenic no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.1 no LT',
#   'climate change: fossil no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.1 no LT',
#   'climate change: land use and land use change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('EF v3.1', 'climate change', 'global warming potential (GWP100)'),
#  ('EF v3.1', 'climate change: biogenic', 'global warming potential (GWP100)'),
#  ('EF v3.1', 'climate change: fossil', 'global warming potential (GWP100)'),
#  ('EF v3.1',
#   'climate change: land use and land use change',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: total (EF v3.0 - IPCC 2013)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: fossil (EF v3.0 - IPCC 2013)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: biogenic (EF v3.0 - IPCC 2013)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: land use and land use change (EF v3.0 - IPCC 2013)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: total (EF v3.1 - IPCC 2021)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: fossil (EF v3.1 - IPCC 2021)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: biogenic (EF v3.1 - IPCC 2021)',
#   'global warming potential (GWP100)'),
#  ('EN15804+A2 - Core impact categories and indicators',
#   'climate change: land use and land use change (EF v3.1 - IPCC 2021)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2013 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2013 no LT',
#   'climate change no LT',
#   'global warming potential (GWP20) no LT'),
#  ('IPCC 2013', 'climate change', 'global warming potential (GWP100)'),
#  ('IPCC 2013', 'climate change', 'global warming potential (GWP20)'),
#  ('IPCC 2021 (incl. biogenic CO2) no LT',
#   'climate change: biogenic (incl. CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 (incl. biogenic CO2) no LT',
#   'climate change: biogenic emissions (incl. CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 (incl. biogenic CO2) no LT',
#   'climate change: biogenic removals (incl. CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 (incl. biogenic CO2) no LT',
#   'climate change: total (incl. biogenic CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 (incl. biogenic CO2) no LT',
#   'climate change: total (incl. biogenic CO2, incl. SLCFs) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 (incl. biogenic CO2)',
#   'climate change: biogenic (incl. CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021 (incl. biogenic CO2)',
#   'climate change: biogenic emissions (incl. CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021 (incl. biogenic CO2)',
#   'climate change: biogenic removals (incl. CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021 (incl. biogenic CO2)',
#   'climate change: total (incl. biogenic CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021 (incl. biogenic CO2)',
#   'climate change: total (incl. biogenic CO2, incl. SLCFs)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021 no LT',
#   'climate change: aircraft emissions no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: biogenic (excl. CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: direct land use change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: emissions from direct land use change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: fossil no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: fossil emissions (excl. aircraft emissions) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: removals from direct land use change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: total (excl. biogenic CO2) no LT',
#   'global warming potential (GWP500) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: total (excl. biogenic CO2) no LT',
#   'global warming potential (GWP20) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: total (excl. biogenic CO2) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: total (excl. biogenic CO2, incl. SLCFs) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: biogenic (excl. CO2, incl. SLCFs) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: fossil (excl. biogenic CO2, incl. SLCFs) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021 no LT',
#   'climate change: direct land use change (incl. SLCFs) no LT',
#   'global warming potential (GWP100) no LT'),
#  ('IPCC 2021',
#   'climate change: aircraft emissions',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: biogenic (excl. CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: direct land use change',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: emissions from direct land use change',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021', 'climate change: fossil', 'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: fossil emissions (excl. aircraft emissions)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: removals from direct land use change',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: total (excl. biogenic CO2)',
#   'global warming potential (GWP500)'),
#  ('IPCC 2021',
#   'climate change: total (excl. biogenic CO2)',
#   'global warming potential (GWP20)'),
#  ('IPCC 2021',
#   'climate change: total (excl. biogenic CO2)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: total (excl. biogenic CO2, incl. SLCFs)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: biogenic (excl. CO2, incl. SLCFs)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: fossil (excl. biogenic CO2, incl. SLCFs)',
#   'global warming potential (GWP100)'),
#  ('IPCC 2021',
#   'climate change: direct land use change (incl. SLCFs)',
#   'global warming potential (GWP100)'),
#  ('ReCiPe 2016 v1.03, midpoint (E) no LT',
#   'climate change no LT',
#   'global warming potential (GWP1000) no LT'),
#  ('ReCiPe 2016 v1.03, midpoint (E)',
#   'climate change',
#   'global warming potential (GWP1000)'),
#  ('ReCiPe 2016 v1.03, midpoint (H) no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('ReCiPe 2016 v1.03, midpoint (H)',
#   'climate change',
#   'global warming potential (GWP100)'),
#  ('ReCiPe 2016 v1.03, midpoint (I) no LT',
#   'climate change no LT',
#   'global warming potential (GWP20) no LT'),
#  ('ReCiPe 2016 v1.03, midpoint (I)',
#   'climate change',
#   'global warming potential (GWP20)'),
#  ('TRACI v2.1 no LT',
#   'climate change no LT',
#   'global warming potential (GWP100) no LT'),
#  ('TRACI v2.1', 'climate change', 'global warming potential (GWP100)')]

# %%
import bw2calc
import numpy as np

# %%
def multiLCA(functional_unit, list_methods):
    
    # Step 1
    lca = bw2calc.LCA(functional_unit)
    lca.lci()
    act_dict = {bw2data.get_activity(k): v for k, v in lca.activity_dict.items()}
    act_dict_rev = {v: k["location"] for k, v in act_dict.items()}
    CH_idx = [k for k, v in act_dict_rev.items() if v=="CH"]
    RoW_idx = [i for i in act_dict_rev if i not in CH_idx]
    
    # Step 2
    C_matrices = {}
    
    # Step 3
    for method in list_methods:
        lca.switch_method(method)
        C_matrices[method] = lca.characterization_matrix
    
    # Step 4
    results_CH, results_RoW = np.empty((len(list_methods))), np.empty((len(list_methods)))
    
    # Step 5
    for method_index, method in enumerate(list_methods):
        r = (C_matrices[method] * lca.inventory)
        results_CH[method_index] = r[:, CH_idx].sum()
        results_RoW[method_index] = r[:, RoW_idx].sum()
            
    return results_CH, results_RoW

# %%
results = []
for k, v in res.items():
    print(k)
    for tech, data in v.items():
        print(f"-- {tech}")
        r = multiLCA({data["dataset"]: 1}, methods)

        results.extend(
            [
                [
                    k, tech, "CH", " - ".join(methods[m])
                ] + [r[0][m]] for m, _ in enumerate(methods)
            ]
        )

        results.extend(
            [
                [
                    k, tech, "RoW", " - ".join(methods[m])
                ] + [r[1][m]] for m, _ in enumerate(methods)
            ]
        )
# Out:
# remind_SSP2-PkBudg1000_2025_SPS1
# -- Solar PV
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si
# remind_SSP2-PkBudg1000_2030_SPS1
# -- Solar PV
# /Users/romain/micromamba/envs/premise/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 8.75e+12)
#   warnings.warn(msg, UmfpackWarning)
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si
# remind_SSP2-PkBudg1000_2035_SPS1
# -- Solar PV
# /Users/romain/micromamba/envs/premise/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.56e+13)
#   warnings.warn(msg, UmfpackWarning)
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si
# remind_SSP2-PkBudg1000_2040_SPS1
# -- Solar PV
# /Users/romain/micromamba/envs/premise/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 7.65e+12)
#   warnings.warn(msg, UmfpackWarning)
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si
# remind_SSP2-PkBudg1000_2045_SPS1
# -- Solar PV
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si
# remind_SSP2-PkBudg1000_2050_SPS1
# -- Solar PV
# -- Wind
# -- Natural Gas Turbine with CSS
# -- Natural Gas Turbine without CCS
# -- Nuclear
# -- Hydrogen Turbine
# -- Hydrogen, from onshore wind power
# -- Hydrogen, from solar photovoltaic
# -- Hydrogen, from hydropower
# -- Battery, Li-ion NMC
# -- Battery, Li-ion LFP
# -- Battery, Li-ion Si

# %%
results
# Out:
# [['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.001264278250621957],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.5050192843274044e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.551595734822434e-12],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.1723897317245244e-12],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   5.430985511021385e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.03460655717750146],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.00354221689805582],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.382730597772645e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.0004947297881597e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.004674217026464272],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.00017698858930173728],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.1269970519111814e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.174480214335316e-13],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.0357953206634348e-12],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.5894909618540824e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.017133717315225342],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0023662592962463242],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.0358631295099998e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.3258873101157536e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0012475935909986495],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.04203205836984965],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.8569529753205246e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   9.507633368330376e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   7.132208647419684e-13],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.7830557060380033e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.07364161684684949],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0016351410733631848],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.338356216952989e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.799358631055751e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.00042080943534196323],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.4390438149027637],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   4.754665200722744e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.2867069786426806e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.9725484878095645e-13],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   7.431383631100453e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0285551369810114],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0008935533625058522],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.193569354280005e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.9913036217371525e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.00030992137119248956],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0001375926466507388],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   5.066561054783107e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.105711903906222e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.521939452875859e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.1304865882972762e-06],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0044885644359124385],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0005777491441185806],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.4569202131712196e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.00702547973665e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0003957673974134138],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.04685689229553162],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.005503269651345586],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   5.696655422897772e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.44477089852018e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.3611945119791094e-06],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0585954636255176],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.014640800107881165],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.826224836354154e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   7.118753317015393e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.011226299677720042],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0027840214906751128],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0006123640799773471],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.637023478113556e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   7.68378612177637e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.920949522840567e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   1.3446327022303703],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.14176069498638413],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.3963356669541228e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.0236155236201921e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.19000626540641322],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.05776856189119402],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0008343013899605066],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.7802653175510004e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.1984678657049264e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.996175279859226e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   1.9240202981252836],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.19813565230989694],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.4406288757647085e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.6334952874767292e-08],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.16309930372425996],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.02330985671264203],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0009639052396342901],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.3968878671942258e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.14404528849671e-11],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.0360131276059285e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.5854628050821983],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.05277706151536246],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   5.98247012867383e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.594726842725629e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.09808841987342315],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.05887161215238285],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.03653660630033098],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.868363845061955e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.431963346868674e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.1079964577195817e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   73.49553140152236],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   5.796756980165265],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   5.270951319638488e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   7.439642412162401e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   6.036149837503581],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.08505197394504066],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.04962632429229649],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.989774318560756e-10],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.971653112682728e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   9.92915468703277e-06],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   96.23702389766322],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   7.842913510029248],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.374833193282294e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.543035219231948e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   7.182214297222133],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.9894398530023216],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.027694883534439448],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.0452850112837428e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   8.377734913740207e-09],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.0944393135061965e-05],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   44.571763918791554],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   3.729465021630786],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.026509082734956e-07],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.2072338610665126e-06],
#  ['remind_SSP2-PkBudg1000_2025_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.107566409754525],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.001235889172210457],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.4410608943627606e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.453774597732543e-12],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.856710896523837e-12],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   4.641787104608574e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.026562662820596373],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0032389880856608043],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.021989611077672e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.5766391467140093e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.005556600606060858],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.00017324876614281632],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.121092493728207e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.061504003570928e-13],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.881044362029076e-13],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.4702635790041406e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.015129576723072649],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0022171124783362524],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   9.375891509901189e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.2629350314682872e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Wind',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0014140644991768483],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.04201120771321044],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.9068200686584383e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.048724637749351e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.926234772036659e-13],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.4815618473381084e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.07170743986019185],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0012228333585794476],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.2393393663860074e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   8.224988552690329e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine with CSS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0004703682742042217],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.4380233258106607],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   4.713697894524449e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.2863397516761908e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.479930697025243e-13],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   6.199837550375011e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.027615291658296258],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0006175672608607103],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.0928796273978643e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.347761993597719e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.00035075507744756394],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.00013284033264589586],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   5.386654639213e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.0776861008638736e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.520923856352617e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.1302326888201405e-06],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.004010846442919905],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0004662013128067125],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.132611834329388e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.005692545420286e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0004377505417751097],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.04304936022016637],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.00815461208629539],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.39960453379092e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.832290698020758e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.2080742606883222e-06],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.03997627184059195],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0170086209079357],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.201554131406103e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.317926592101668e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.013003611386597929],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.002647338116767744],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0006081993911545226],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.5954603001990045e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.806643727885141e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.7016635673632538e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   1.1651132934077721],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.12625408864338175],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.303006200305646e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.062118843857278e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.22177238434148488],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0562736880190681],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0008114807060601629],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.7295902125633558e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.0154516035391887e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.5386338353997346e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   1.5008227290476581],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.1771704292655437],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.2474645116709973e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.3867916843463266e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.18960135324675706],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.023310070938873526],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0009610575149102982],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.396448761413951e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.2802204662889274e-11],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   8.200565628090916e-08],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.5008086467664222],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.042734091560659396],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   5.502757339039222e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.4355067320073476e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.11271486553085772],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.06349804036915899],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.035139480988513314],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.8990578493439433e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.019058731908707e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.0047700344507772e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   57.97155760224321],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   5.172152330811151],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.5104357681137143e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.846883132096075e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   6.994915324886361],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.08934044669807303],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.04659912654498482],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.937707224222044e-10],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.626304787509397e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   9.065782307703119e-06],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   73.5932270622399],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   6.8865534245932745],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   6.217359764701077e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.074411913667865e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   8.187494386652677],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.9936456704256145],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.027690698056130322],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.0503397030547192e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.7635891714115635e-09],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.6909022290942675e-05],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   34.35631745060844],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   3.5615054859892457],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.599627255135005e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.915060782341406e-07],
#  ['remind_SSP2-PkBudg1000_2030_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.5081456876192774],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0012111531205149751],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   1.425679328592305e-05],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.3788455792098504e-12],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.6202501276714514e-12],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   4.0506349060629556e-09],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.019268317421917997],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0031011889658800577],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.7261777844320205e-10],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.2871764008941623e-10],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Solar PV',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.00642910299390105],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Wind',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.00017335127704654185],
#  ['remind_SSP2-PkBudg1000_2035_SPS1',
#   'Wind',
#   'CH',
# ...
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.057458597310394e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.4903419867808756e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Natural Gas Turbine without CCS',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.00037705861571636715],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   7.894387889651135e-05],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   8.017765291435369e-05],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.081976996203538e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.5144275531520954e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.1286086110396514e-06],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.0016599155079870987],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.0005453387256800126],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.4771614659866173e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.997258989418974e-08],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Nuclear',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.0006090345903750252],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   -0.17548828344996875],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.06415807905787015],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.3600964349108084e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.194124250222598e-12],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   2.298535371022889e-08],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   -0.09359099088204266],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.09187052536248766],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   7.383274560430686e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   1.2530892884142656e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen Turbine',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.014203385814263135],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.00256800164680197],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0005845237178442252],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.5551425823903095e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.097732764266317e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.0244356491262895e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.5552485005322009],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.1101987066892282],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   8.55244755281372e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.8003971268591516e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from onshore wind power',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.24661891373891986],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.05078355909903271],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0008228173351937359],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.5704340853817468e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.9945805880412795e-11],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.2486479638905062e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.5447191398318757],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.15729229879517692],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   6.519396540323264e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.997203771365845e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from solar photovoltaic',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.16523069690586195],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.023096225926741765],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0009459473446797534],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.3957981460876327e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   6.515472801821125e-12],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   1.6288727007067388e-08],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.16653135903129998],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   0.025608918836804353],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   1.9826208050077016e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   9.461175363307058e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Hydrogen, from hydropower',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   0.07319570531742448],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.06838171608544175],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.0319774078800711],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.885311624765847e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.9658272850044267e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   7.414615543626478e-06],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   21.995106712139435],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   4.306152450072748],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.8742156981925126e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   5.362052880318665e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion NMC',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   10.32673549946271],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.08846167209755296],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.039359006684754144],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   4.5814974234877986e-10],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.831244117689887e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   7.0781284984419e-06],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   25.42796147708824],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   5.312889844006476],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.7666470625616586e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   4.0535199024416517e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion LFP',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   11.308259499651578],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   0.9996623501230029],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - resources - land occupation',
#   0.028642306026832015],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   3.0718368863109833e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   2.071211192325758e-09],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'CH',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   5.178059907920965e-06],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'IPCC 2021 (incl. biogenic CO2) - climate change: total (incl. biogenic CO2, incl. SLCFs) - global warming potential (GWP100)',
#   20.265518726075392],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - resources - land occupation',
#   2.7803088288986584],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
#   2.021830736328313e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total volume of radioactive waste',
#   3.699992390696057e-07],
#  ['remind_SSP2-PkBudg1000_2050_SPS1',
#   'Battery, Li-ion Si',
#   'RoW',
#   'Inventory results and indicators - waste disposal - total mass for underground deposits',
#   3.9909899173155967]]

# %%
import pandas as pd
df = pd.DataFrame(results, columns=["database", "technology", "location", "impact category", "score"])
df.to_excel("indicators_for_Christian.xlsx")

# %%
import pandas as pd

# Assuming your dataframe is called df
pivoted = df.pivot_table(
    index=["database", "technology", "impact category"],
    columns="location",
    values="score"
).reset_index()

# Optional: flatten columns if needed
pivoted.columns.name = None

# %%
pivoted.to_excel("indicators_for_Christian.xlsx")
