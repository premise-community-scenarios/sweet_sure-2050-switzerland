# %%
import numpy as np
from pathways import Pathways

# %%
for scenario in [
    "remind-SSP2-PkBudg1000-stem-SPS1.zip",
    "remind-SSP2-PkBudg1000-stem-SPS2.zip",
    "remind-SSP2-PkBudg1000-stem-SPS3.zip",
    "remind-SSP2-PkBudg1000-stem-SPS4.zip",
]:
    p = Pathways(datapackage=scenario, debug=False)

    p.calculate(
        methods=[
            'EF v3.1 EN15804 - climate change - global warming potential (GWP100)',
            'EF v3.1 EN15804 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)',
            'Inventory results and indicators - resources - land occupation',
            'EN15804 - inventory indicators ISO21930 - use of net fresh water',
            'ReCiPe 2016 v1.03, endpoint (H) - total: human health - human health',
            'ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ecosystem quality',
        ]
        ,
        regions=["CH",],
        scenarios=p.scenarios.pathway.values.tolist(),
        variables=[v for v in p.scenarios.coords["variables"].values if v.startswith("EXT - 0 - FE")],
        years=[
            2020,
            2025,
            2030,
            2035,
            2040,
            2050
        ],
        multiprocessing=True,
        use_distributions=0,
        # subshares=True,
    )
    p.export_results(filename=scenario.replace(".zip", "").replace("remind", "results_remind"))
    del p
# Out:
# [2020 2025 2030 2035 2040 2045 2050]
# ['EXT - 0 - CAES' 'EXT - 0 - DH_CHP_fossil_waste'
#  'EXT - 0 - DH_CHP_fossil_waste_CCS' 'EXT - 0 - DH_CHP_gas'
#  'EXT - 0 - DH_CHP_hydrogen' 'EXT - 0 - DH_CHP_renew_waste'
#  'EXT - 0 - DH_CHP_renew_waste_CCS' 'EXT - 0 - DH_CHP_wood'
#  'EXT - 0 - DH_geothermal' 'EXT - 0 - DH_heat_pump' 'EXT - 0 - DH_nuclear'
#  'EXT - 0 - DH_solar' 'EXT - 0 - DH_wood' 'EXT - 0 - FE_bus_diesel'
#  'EXT - 0 - FE_bus_electricity' 'EXT - 0 - FE_bus_gas'
#  'EXT - 0 - FE_bus_hydrogen' 'EXT - 0 - FE_cars_diesel'
#  'EXT - 0 - FE_cars_electricity' 'EXT - 0 - FE_cars_gas'
#  'EXT - 0 - FE_cars_gasoline' 'EXT - 0 - FE_cars_hydrogen'
#  'EXT - 0 - FE_coach_diesel' 'EXT - 0 - FE_coach_electricity'
#  'EXT - 0 - FE_coach_gas' 'EXT - 0 - FE_coach_hydrogen'
#  'EXT - 0 - FE_heavy_duty_truck_diesel'
#  'EXT - 0 - FE_heavy_duty_truck_electricity'
#  'EXT - 0 - FE_heavy_duty_truck_gas'
#  'EXT - 0 - FE_heavy_duty_truck_gasoline'
#  'EXT - 0 - FE_heavy_duty_truck_hydrogen'
#  'EXT - 0 - FE_industry_heat_CHP_gas'
#  'EXT - 0 - FE_industry_heat_CHP_gas_CCS'
#  'EXT - 0 - FE_industry_heat_CHP_hydrogen'
#  'EXT - 0 - FE_industry_heat_CHP_oil'
#  'EXT - 0 - FE_industry_heat_CHP_waste_non_renew'
#  'EXT - 0 - FE_industry_heat_CHP_waste_non_renew_CCS'
#  'EXT - 0 - FE_industry_heat_CHP_wood'
#  'EXT - 0 - FE_industry_heat_CHP_wood_CCS'
#  'EXT - 0 - FE_industry_process_FE_other_electric'
#  'EXT - 0 - FE_industry_process_biomethane'
#  'EXT - 0 - FE_industry_process_coal'
#  'EXT - 0 - FE_industry_process_electric_boiler'
#  'EXT - 0 - FE_industry_process_heat_pump'
#  'EXT - 0 - FE_industry_process_heavy_fuel_oil'
#  'EXT - 0 - FE_industry_process_hydrogen'
#  'EXT - 0 - FE_industry_process_light_fuel_oil'
#  'EXT - 0 - FE_industry_process_natural_gas'
#  'EXT - 0 - FE_industry_process_pellet'
#  'EXT - 0 - FE_industry_process_solar'
#  'EXT - 0 - FE_industry_process_waste_non_renew'
#  'EXT - 0 - FE_industry_process_waste_renew'
#  'EXT - 0 - FE_industry_process_wood'
#  'EXT - 0 - FE_light_duty_truck_diesel'
#  'EXT - 0 - FE_light_duty_truck_electricity'
#  'EXT - 0 - FE_light_duty_truck_gas'
#  'EXT - 0 - FE_light_duty_truck_gasoline'
#  'EXT - 0 - FE_light_duty_truck_hydrogen'
#  'EXT - 0 - FE_motorcycle_electric' 'EXT - 0 - FE_motorcycle_gasoline'
#  'EXT - 0 - FE_motorcycle_hydrogen' 'EXT - 0 - FE_other_transport_diesel'
#  'EXT - 0 - FE_other_transport_electric'
#  'EXT - 0 - FE_other_transport_gasoline'
#  'EXT - 0 - FE_other_transport_hydrogen'
#  'EXT - 0 - FE_residential_FE_other_electric'
#  'EXT - 0 - FE_residential_space_heating_CHP_fuel_cell'
#  'EXT - 0 - FE_residential_space_heating_CHP_gas'
#  'EXT - 0 - FE_residential_space_heating_CHP_wood'
#  'EXT - 0 - FE_residential_space_heating_DH'
#  'EXT - 0 - FE_residential_space_heating_coal'
#  'EXT - 0 - FE_residential_space_heating_electric_boiler'
#  'EXT - 0 - FE_residential_space_heating_gas'
#  'EXT - 0 - FE_residential_space_heating_heat_pump'
#  'EXT - 0 - FE_residential_space_heating_heat_pump_gas'
#  'EXT - 0 - FE_residential_space_heating_hydrogen'
#  'EXT - 0 - FE_residential_space_heating_light_fuel_oil'
#  'EXT - 0 - FE_residential_space_heating_pellet'
#  'EXT - 0 - FE_residential_space_heating_solar'
#  'EXT - 0 - FE_residential_space_heating_wood'
#  'EXT - 0 - FE_residential_water_heating_coal'
#  'EXT - 0 - FE_residential_water_heating_electric_boiler'
#  'EXT - 0 - FE_residential_water_heating_gas'
#  'EXT - 0 - FE_residential_water_heating_heat_pump'
#  'EXT - 0 - FE_residential_water_heating_heat_pump_gas'
#  'EXT - 0 - FE_residential_water_heating_hydrogen'
#  'EXT - 0 - FE_residential_water_heating_light_fuel_oil'
#  'EXT - 0 - FE_residential_water_heating_pellet'
#  'EXT - 0 - FE_residential_water_heating_solar'
#  'EXT - 0 - FE_residential_water_heating_wood'
#  'EXT - 0 - FE_services_CHP_biogas' 'EXT - 0 - FE_services_CHP_fuel_cell'
#  'EXT - 0 - FE_services_CHP_gas' 'EXT - 0 - FE_services_CHP_hydrogen'
#  'EXT - 0 - FE_services_CHP_wood' 'EXT - 0 - FE_services_biomethane'
#  'EXT - 0 - FE_services_electric_boiler' 'EXT - 0 - FE_services_heat_pump'
#  'EXT - 0 - FE_services_hydrogen' 'EXT - 0 - FE_services_light_fuel_oil'
#  'EXT - 0 - FE_services_natural_gas'
#  'EXT - 0 - FE_services_other_electric' 'EXT - 0 - FE_services_pellet'
#  'EXT - 0 - FE_services_solar' 'EXT - 0 - FE_services_wood'
#  'EXT - 0 - FE_tram' 'EXT - 0 - FE_trolleybus'
#  'EXT - 0 - battery (industry)' 'EXT - 0 - battery (large)'
#  'EXT - 0 - battery (medium)' 'EXT - 0 - battery (multi family)'
#  'EXT - 0 - battery (services)' 'EXT - 0 - battery (single family)'
#  'EXT - 0 - biodiesel (import)' 'EXT - 0 - biodiesel, wood, FT (domestic)'
#  'EXT - 0 - biodiesel, wood, FT w CCS (domestic)'
#  'EXT - 0 - bioethanol (domestic)' 'EXT - 0 - bioethanol (import)'
#  'EXT - 0 - bioethanol, w CCS (domestic)'
#  'EXT - 0 - biogas (services CHP)'
#  'EXT - 0 - biogas, fermentation, biomass (domestic)'
#  'EXT - 0 - biogas, fermentation, sewage sludge (domestic)'
#  'EXT - 0 - biomass (CCS, BECCS)' 'EXT - 0 - biomass (CHP)'
#  'EXT - 0 - biomass (DH)' 'EXT - 0 - biomethane (domestic)'
#  'EXT - 0 - biomethane (import)' 'EXT - 0 - fossil diesel (import)'
#  'EXT - 0 - fossil gasoline (import)' 'EXT - 0 - gas (CCGT CCS)'
#  'EXT - 0 - gas (CCGT)' 'EXT - 0 - gas (CHP CCS industry)'
#  'EXT - 0 - gas (CHP DH)' 'EXT - 0 - gas (CHP fuel cell reformer)'
#  'EXT - 0 - gas (CHP industry)' 'EXT - 0 - gas (CHP single family)'
#  'EXT - 0 - gas (OCGT)' 'EXT - 0 - gas (fuel cell DH)'
#  'EXT - 0 - gas (multi family CHP fuel cell)'
#  'EXT - 0 - gas (multi family CHP)'
#  'EXT - 0 - gas (services CHP fuel cell)' 'EXT - 0 - gas (services CHP)'
#  'EXT - 0 - gas (single family CHP fuel cell)' 'EXT - 0 - geothermal'
#  'EXT - 0 - heavy fuel oil' 'EXT - 0 - hydro (pumped storage)'
#  'EXT - 0 - hydro (reservoir)' 'EXT - 0 - hydro_run_of_river'
#  'EXT - 0 - hydrogen (import)' 'EXT - 0 - hydrogen fuel cell (DH CHP)'
#  'EXT - 0 - hydrogen fuel cell (industrial CHP)'
#  'EXT - 0 - hydrogen fuel cell (services CHP)'
#  'EXT - 0 - hydrogen, PEM, large (domestic)'
#  'EXT - 0 - hydrogen, SOEC, large (domestic)'
#  'EXT - 0 - hydrogen, wood gasification (domestic)'
#  'EXT - 0 - hydrogen, wood gasification w CCS (domestic)'
#  'EXT - 0 - import' 'EXT - 0 - kerosene (import)'
#  'EXT - 0 - light_fuel_oil' 'EXT - 0 - lng (import)'
#  'EXT - 0 - low_to_medium' 'EXT - 0 - medium_to_high'
#  'EXT - 0 - natural gas (import)' 'EXT - 0 - nuclear (boiling water)'
#  'EXT - 0 - nuclear (pressure water)' 'EXT - 0 - oil (DH CHP)'
#  'EXT - 0 - oil (industry CHP)' 'EXT - 0 - oil (peak devices)'
#  'EXT - 0 - pv (industry)' 'EXT - 0 - pv (large scale)'
#  'EXT - 0 - pv (services)' 'EXT - 0 - pv residential (multi family)'
#  'EXT - 0 - pv residential (single family)'
#  'EXT - 0 - synthetic diesel (domestic)'
#  'EXT - 0 - synthetic diesel (import)'
#  'EXT - 0 - synthetic gasoline (import)'
#  'EXT - 0 - synthetic kerosene (domestic)'
#  'EXT - 0 - synthetic kerosene (import)'
#  'EXT - 0 - synthetic natural gas (domestic)'
#  'EXT - 0 - synthetic natural gas (import)'
#  'EXT - 0 - waste incineration, fossil (CHP)'
#  'EXT - 0 - waste incineration, fossil (CHP, CCS)'
#  'EXT - 0 - waste incineration, fossil (industrial)'
#  'EXT - 0 - waste incineration, fossil (industrial, CCS)'
#  'EXT - 0 - waste incineration, non-fossil (CHP)'
#  'EXT - 0 - waste incineration, non-fossil (CHP, CCS)'
#  'EXT - 0 - waste incineration, non-fossil (industrial)'
#  'EXT - 0 - waste incineration, non-fossil (industrial, CCS)'
#  'EXT - 0 - wind' 'EXT - 0 - wood (forest)'
#  'EXT - 0 - wood (landscape maintenance)' 'EXT - 0 - wood (residues)'
#  'EXT - 0 - wood (waste)'
#  'FE - final energy - Buildings - Heating - Biofuel'
#  'FE - final energy - Buildings - Heating - District Heating'
#  'FE - final energy - Buildings - Heating - Gases'
#  'FE - final energy - Buildings - Heating - H2'
#  'FE - final energy - Buildings - Heating - Heat pump'
#  'FE - final energy - Buildings - Heating - LPG'
#  'FE - final energy - Buildings - Heating - Liquid coal'
#  'FE - final energy - Buildings - Heating - Oil'
#  'FE - final energy - Buildings - Heating - Resistance'
#  'FE - final energy - Buildings - Heating - Solid Coal'
#  'FE - final energy - Buildings - Heating - Solid biomass modern'
#  'FE - final energy - Buildings - Heating - Solid biomass traditional'
#  'FE - final energy - Buildings - Heating - Syn Fuel'
#  'FE - final energy - Buildings - Other - Elec'
#  'FE - final energy - CDR - DAC - Elec'
#  'FE - final energy - CDR - DAC - Gases'
#  'FE - final energy - CDR - DAC - H2'
#  'FE - final energy - CDR - DAC - Heat'
#  'FE - final energy - CDR - Enhanced Weathering - Diesel'
#  'FE - final energy - CDR - Enhanced Weathering - Elec'
#  'FE - final energy - CDR - OAE, electric calciner - Diesel'
#  'FE - final energy - CDR - OAE, electric calciner - Elec'
#  'FE - final energy - CDR - OAE, electric calciner - H2'
#  'FE - final energy - CDR - OAE, traditional calciner - Diesel'
#  'FE - final energy - CDR - OAE, traditional calciner - Elec'
#  'FE - final energy - CDR - OAE, traditional calciner - Gases'
#  'FE - final energy - CDR - OAE, traditional calciner - Hydrogen'
#  'FE - final energy - Industry - Cement - Bio CH4'
#  'FE - final energy - Industry - Cement - Biofuel'
#  'FE - final energy - Industry - Cement - Elec'
#  'FE - final energy - Industry - Cement - H2'
#  'FE - final energy - Industry - Cement - Nat Gas'
#  'FE - final energy - Industry - Cement - Oil'
#  'FE - final energy - Industry - Cement - SNG'
#  'FE - final energy - Industry - Cement - Solid biomass'
#  'FE - final energy - Industry - Cement - Solid coal'
#  'FE - final energy - Industry - Cement - Syn Fuel'
#  'FE - final energy - Industry - Chemicals - Chemicals - Bio CH4'
#  'FE - final energy - Industry - Chemicals - Chemicals - Biofuel'
#  'FE - final energy - Industry - Chemicals - Chemicals - Elec, high temp'
#  'FE - final energy - Industry - Chemicals - Chemicals - Elec, low temp'
#  'FE - final energy - Industry - Chemicals - Chemicals - H2'
#  'FE - final energy - Industry - Chemicals - Chemicals - Liquid fossil'
#  'FE - final energy - Industry - Chemicals - Chemicals - Nat Gas'
#  'FE - final energy - Industry - Chemicals - Chemicals - SNG'
#  'FE - final energy - Industry - Chemicals - Chemicals - Solid Biomass'
#  'FE - final energy - Industry - Chemicals - Chemicals - Solid coal'
#  'FE - final energy - Industry - Chemicals - Chemicals - Syn Fuel'
#  'FE - final energy - Industry - Chemicals - Elec'
#  'FE - final energy - Industry - Non-energy use - Bio CH4'
#  'FE - final energy - Industry - Non-energy use - Biofuel'
#  'FE - final energy - Industry - Non-energy use - Biomass'
#  'FE - final energy - Industry - Non-energy use - Hydrogen'
#  'FE - final energy - Industry - Non-energy use - Liquid fossil'
#  'FE - final energy - Industry - Non-energy use - Nat Gas'
#  'FE - final energy - Industry - Non-energy use - Solid coal'
#  'FE - final energy - Industry - Non-energy use - Syn Fuel'
#  'FE - final energy - Industry - Other - Bio CH4'
#  'FE - final energy - Industry - Other - Biofuel'
#  'FE - final energy - Industry - Other - Elec'
#  'FE - final energy - Industry - Other - Elec, high temp'
#  'FE - final energy - Industry - Other - Elec, low temp'
#  'FE - final energy - Industry - Other - H2'
#  'FE - final energy - Industry - Other - Heat'
#  'FE - final energy - Industry - Other - Liquid fossil'
#  'FE - final energy - Industry - Other - Nat Gas'
#  'FE - final energy - Industry - Other - SNG'
#  'FE - final energy - Industry - Other - Solid Biomass'
#  'FE - final energy - Industry - Other - Solid coal'
#  'FE - final energy - Industry - Other - Syn Fuel'
#  'FE - final energy - Industry - Steel - All steel - Bio CH4'
#  'FE - final energy - Industry - Steel - All steel - Biofuel'
#  'FE - final energy - Industry - Steel - All steel - Elec'
#  'FE - final energy - Industry - Steel - All steel - H2'
#  'FE - final energy - Industry - Steel - All steel - Liquid fossil'
#  'FE - final energy - Industry - Steel - All steel - Nat Gas'
#  'FE - final energy - Industry - Steel - All steel - SNG'
#  'FE - final energy - Industry - Steel - All steel - Solid Biomass'
#  'FE - final energy - Industry - Steel - All steel - Solid coal'
#  'FE - final energy - Industry - Steel - All steel - Syn Fuel'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Biofuel'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Liquid fossil'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Syn Fuel'
#  'FE - final energy - Transport - Freight - Int. Shipping - Biofuel'
#  'FE - final energy - Transport - Freight - Int. Shipping - Liquid fossil'
#  'FE - final energy - Transport - Freight - Int. Shipping - Syn Fuel'
#  'FE - final energy - Transport - Freight - Rail - Biofuel'
#  'FE - final energy - Transport - Freight - Rail - Elec'
#  'FE - final energy - Transport - Freight - Rail - Liquid fossil'
#  'FE - final energy - Transport - Freight - Rail - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(18t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(18t) - H2'
#  'FE - final energy - Transport - Freight - Truck(18t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(18t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(18t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(18t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(26t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(26t) - H2'
#  'FE - final energy - Transport - Freight - Truck(26t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(26t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(26t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(26t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(40t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(40t) - H2'
#  'FE - final energy - Transport - Freight - Truck(40t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(40t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(40t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(40t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Bus - Bio CH4'
#  'FE - final energy - Transport - Pass - Bus - Biofuel'
#  'FE - final energy - Transport - Pass - Bus - Elec'
#  'FE - final energy - Transport - Pass - Bus - H2'
#  'FE - final energy - Transport - Pass - Bus - Liquid fossil'
#  'FE - final energy - Transport - Pass - Bus - Nat Gas'
#  'FE - final energy - Transport - Pass - Bus - SNG'
#  'FE - final energy - Transport - Pass - Bus - Syn Fuel'
#  'FE - final energy - Transport - Pass - Compact Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Compact Car - Biofuel'
#  'FE - final energy - Transport - Pass - Compact Car - Elec'
#  'FE - final energy - Transport - Pass - Compact Car - H2'
#  'FE - final energy - Transport - Pass - Compact Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Compact Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Compact Car - SNG'
#  'FE - final energy - Transport - Pass - Compact Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - H2'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Int Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car - Elec'
#  'FE - final energy - Transport - Pass - Large Car - H2'
#  'FE - final energy - Transport - Pass - Large Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car - SNG'
#  'FE - final energy - Transport - Pass - Large Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Elec'
#  'FE - final energy - Transport - Pass - Large Car and SUV - H2'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car and SUV - SNG'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Syn Fuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Midsize Car - Biofuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Elec'
#  'FE - final energy - Transport - Pass - Midsize Car - H2'
#  'FE - final energy - Transport - Pass - Midsize Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Midsize Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Midsize Car - SNG'
#  'FE - final energy - Transport - Pass - Midsize Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Mini Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Mini Car - Biofuel'
#  'FE - final energy - Transport - Pass - Mini Car - Elec'
#  'FE - final energy - Transport - Pass - Mini Car - H2'
#  'FE - final energy - Transport - Pass - Mini Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Mini Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Mini Car - SNG'
#  'FE - final energy - Transport - Pass - Mini Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Moped - Biofuel'
#  'FE - final energy - Transport - Pass - Moped - Elec'
#  'FE - final energy - Transport - Pass - Moped - Liquid fossil'
#  'FE - final energy - Transport - Pass - Moped - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Rail - Biofuel'
#  'FE - final energy - Transport - Pass - Rail - Elec'
#  'FE - final energy - Transport - Pass - Rail - Liquid fossil'
#  'FE - final energy - Transport - Pass - Rail - Syn Fuel'
#  'FE - final energy - Transport - Pass - Subcompact Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Subcompact Car - Biofuel'
#  'FE - final energy - Transport - Pass - Subcompact Car - Elec'
#  'FE - final energy - Transport - Pass - Subcompact Car - H2'
#  'FE - final energy - Transport - Pass - Subcompact Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Subcompact Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Subcompact Car - SNG'
#  'FE - final energy - Transport - Pass - Subcompact Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Van - Bio CH4'
#  'FE - final energy - Transport - Pass - Van - Biofuel'
#  'FE - final energy - Transport - Pass - Van - Elec'
#  'FE - final energy - Transport - Pass - Van - H2'
#  'FE - final energy - Transport - Pass - Van - Liquid fossil'
#  'FE - final energy - Transport - Pass - Van - Nat Gas'
#  'FE - final energy - Transport - Pass - Van - SNG'
#  'FE - final energy - Transport - Pass - Van - Syn Fuel'
#  'SE - bus - bus, battery electric' 'SE - bus - bus, compressed gas'
#  'SE - bus - bus, diesel' 'SE - bus - bus, fuel cell'
#  'SE - car - passenger car, battery electric, large'
#  'SE - car - passenger car, battery electric, medium'
#  'SE - car - passenger car, battery electric, medium SUV'
#  'SE - car - passenger car, battery electric, mini'
#  'SE - car - passenger car, battery electric, small'
#  'SE - car - passenger car, battery electric, van'
#  'SE - car - passenger car, compressed gas, large'
#  'SE - car - passenger car, compressed gas, medium'
#  'SE - car - passenger car, compressed gas, medium SUV'
#  'SE - car - passenger car, compressed gas, mini'
#  'SE - car - passenger car, compressed gas, small'
#  'SE - car - passenger car, compressed gas, van'
#  'SE - car - passenger car, fuel cell electric, large'
#  'SE - car - passenger car, fuel cell electric, medium'
#  'SE - car - passenger car, fuel cell electric, medium SUV'
#  'SE - car - passenger car, fuel cell electric, mini'
#  'SE - car - passenger car, fuel cell electric, small'
#  'SE - car - passenger car, fuel cell electric, van'
#  'SE - car - passenger car, gasoline, large'
#  'SE - car - passenger car, gasoline, medium'
#  'SE - car - passenger car, gasoline, medium SUV'
#  'SE - car - passenger car, gasoline, mini'
#  'SE - car - passenger car, gasoline, small'
#  'SE - car - passenger car, gasoline, van'
#  'SE - car - passenger car, plugin gasoline hybrid, large'
#  'SE - car - passenger car, plugin gasoline hybrid, medium'
#  'SE - car - passenger car, plugin gasoline hybrid, medium SUV'
#  'SE - car - passenger car, plugin gasoline hybrid, mini'
#  'SE - car - passenger car, plugin gasoline hybrid, small'
#  'SE - car - passenger car, plugin gasoline hybrid, van'
#  'SE - cdr - biomass power generation, with CCS'
#  'SE - cdr - direct air capture (solvent) with storage'
#  'SE - cdr - enhanced rock weathering' 'SE - cdr - ocean liming'
#  'SE - cdr - synthetic fuels, with CCS'
#  'SE - cement - cement, dry feed rotary kiln'
#  'SE - cement - cement, dry feed rotary kiln, efficient, with MEA CCS'
#  'SE - electricity - Biomass CHP' 'SE - electricity - Biomass IGCC'
#  'SE - electricity - Biomass IGCC CCS' 'SE - electricity - Coal CHP'
#  'SE - electricity - Coal IGCC' 'SE - electricity - Coal IGCC CCS'
#  'SE - electricity - Coal PC' 'SE - electricity - Gas CC'
#  'SE - electricity - Gas CC CCS' 'SE - electricity - Gas CHP'
#  'SE - electricity - Gas OC' 'SE - electricity - Gas ST'
#  'SE - electricity - Geothermal' 'SE - electricity - Hydro'
#  'SE - electricity - Nuclear' 'SE - electricity - Oil ST'
#  'SE - electricity - Solar CSP' 'SE - electricity - Solar PV Centralized'
#  'SE - electricity - Storage, Hydrogen' 'SE - electricity - Wind Offshore'
#  'SE - electricity - Wind Onshore'
#  'SE - fuels - biodiesel, from oil crops'
#  'SE - fuels - bioethanol, from grass'
#  'SE - fuels - bioethanol, from residues'
#  'SE - fuels - bioethanol, from sugar'
#  'SE - fuels - bioethanol, from wood'
#  'SE - fuels - bioethanol, from wood, with CCS' 'SE - fuels - diesel'
#  'SE - fuels - diesel, synthetic, from coal'
#  'SE - fuels - diesel, synthetic, from coal, with CCS'
#  'SE - fuels - diesel, synthetic, from electrolysis'
#  'SE - fuels - diesel, synthetic, from wood'
#  'SE - fuels - diesel, synthetic, from wood, with CCS'
#  'SE - fuels - gasoline' 'SE - fuels - hydrogen, from biomass'
#  'SE - fuels - hydrogen, from biomass, with CCS'
#  'SE - fuels - hydrogen, from coal'
#  'SE - fuels - hydrogen, from coal, with CCS'
#  'SE - fuels - hydrogen, from electrolysis, PEM'
#  'SE - fuels - hydrogen, from natural gas'
#  'SE - fuels - hydrogen, from natural gas, with CCS'
#  'SE - fuels - methane, from biomass' 'SE - fuels - natural gas'
#  'SE - fuels - petrol, synthetic, from coal'
#  'SE - fuels - petrol, synthetic, from coal, with CCS'
#  'SE - fuels - petrol, synthetic, from electrolysis'
#  'SE - heat - energy, for DACCS, from electricity'
#  'SE - heat - energy, for DACCS, from gas boiler'
#  'SE - heat - energy, for DACCS, from hydrogen turbine'
#  'SE - heat - energy, for DACCS, from other'
#  'SE - heat - energy, for EWR, from electricity'
#  'SE - heat - energy, from EWR, from diesel'
#  'SE - heat - heat, buildings, from LPG boiler'
#  'SE - heat - heat, buildings, from biomass-based methanol boiler'
#  'SE - heat - heat, buildings, from coal stove'
#  'SE - heat - heat, buildings, from coal-based methanol boiler'
#  'SE - heat - heat, buildings, from district heating'
#  'SE - heat - heat, buildings, from electric heater'
#  'SE - heat - heat, buildings, from heat pump'
#  'SE - heat - heat, buildings, from hydrogen boiler'
#  'SE - heat - heat, buildings, from light fuel oil boiler'
#  'SE - heat - heat, buildings, from natural gas'
#  'SE - heat - heat, buildings, from wood logs heater'
#  'SE - heat - heat, buildings, from wood pellets heater'
#  'SE - heat - heat, industrial, from biomass CHP'
#  'SE - heat - heat, industrial, from coal CHP'
#  'SE - heat - heat, industrial, from geothermal'
#  'SE - heat - heat, industrial, from heat pump'
#  'SE - heat - heat, industrial, from natural gas CHP'
#  'SE - heat - heat, industrial, from solar thermal'
#  'SE - ship - ship, ammonia' 'SE - ship - ship, biodiesel'
#  'SE - ship - ship, marine oil' 'SE - steel - steel - primary - BF/BOF'
#  'SE - steel - steel - primary - BF/BOF CCS'
#  'SE - steel - steel - primary - DRI'
#  'SE - steel - steel - primary - DRI CCS'
#  'SE - steel - steel - primary - H-DRI' 'SE - steel - steel - secondary'
#  'SE - train - train, diesel-electric' 'SE - train - train, electric'
#  'SE - train - train, fuel cell'
#  'SE - truck - truck, battery electric, 18 metric ton'
#  'SE - truck - truck, battery electric, 26 metric ton'
#  'SE - truck - truck, battery electric, 3.5 metric ton'
#  'SE - truck - truck, battery electric, 40 metric ton'
#  'SE - truck - truck, battery electric, 7.5 metric ton'
#  'SE - truck - truck, compressed gas, 18 metric ton'
#  'SE - truck - truck, compressed gas, 26 metric ton'
#  'SE - truck - truck, compressed gas, 3.5 metric ton'
#  'SE - truck - truck, compressed gas, 40 metric ton'
#  'SE - truck - truck, compressed gas, 7.5 metric ton'
#  'SE - truck - truck, diesel, 18 metric ton'
#  'SE - truck - truck, diesel, 26 metric ton'
#  'SE - truck - truck, diesel, 3.5 metric ton'
#  'SE - truck - truck, diesel, 40 metric ton'
#  'SE - truck - truck, diesel, 7.5 metric ton'
#  'SE - truck - truck, fuel cell electric, 18 metric ton'
#  'SE - truck - truck, fuel cell electric, 26 metric ton'
#  'SE - truck - truck, fuel cell electric, 3.5 metric ton'
#  'SE - truck - truck, fuel cell electric, 40 metric ton'
#  'SE - truck - truck, fuel cell electric, 7.5 metric ton'
#  'SE - two-wheeler - moped, battery electric'
#  'SE - two-wheeler - moped, gasoline'
#  'SE - two-wheeler - motorcycle, 50-250cc, battery electric'
#  'SE - two-wheeler - motorcycle, 50-250cc, gasoline'
#  'SE - two-wheeler - motorcycle, >250cc, battery electric'
#  'SE - two-wheeler - motorcycle, >250cc, gasoline']
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS1...
# ------ Calculating LCA results for 2020...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS1.gzip
# [2020 2025 2030 2035 2040 2045 2050]
# ['EXT - 0 - CAES' 'EXT - 0 - DH_CHP_fossil_waste'
#  'EXT - 0 - DH_CHP_fossil_waste_CCS' 'EXT - 0 - DH_CHP_gas'
#  'EXT - 0 - DH_CHP_hydrogen' 'EXT - 0 - DH_CHP_renew_waste'
#  'EXT - 0 - DH_CHP_renew_waste_CCS' 'EXT - 0 - DH_CHP_wood'
#  'EXT - 0 - DH_geothermal' 'EXT - 0 - DH_heat_pump' 'EXT - 0 - DH_nuclear'
#  'EXT - 0 - DH_solar' 'EXT - 0 - DH_wood' 'EXT - 0 - FE_bus_diesel'
#  'EXT - 0 - FE_bus_electricity' 'EXT - 0 - FE_bus_gas'
#  'EXT - 0 - FE_bus_hydrogen' 'EXT - 0 - FE_cars_diesel'
#  'EXT - 0 - FE_cars_electricity' 'EXT - 0 - FE_cars_gas'
#  'EXT - 0 - FE_cars_gasoline' 'EXT - 0 - FE_cars_hydrogen'
#  'EXT - 0 - FE_coach_diesel' 'EXT - 0 - FE_coach_electricity'
#  'EXT - 0 - FE_coach_gas' 'EXT - 0 - FE_coach_hydrogen'
#  'EXT - 0 - FE_heavy_duty_truck_diesel'
#  'EXT - 0 - FE_heavy_duty_truck_electricity'
#  'EXT - 0 - FE_heavy_duty_truck_gas'
#  'EXT - 0 - FE_heavy_duty_truck_gasoline'
#  'EXT - 0 - FE_heavy_duty_truck_hydrogen'
#  'EXT - 0 - FE_industry_heat_CHP_gas'
#  'EXT - 0 - FE_industry_heat_CHP_gas_CCS'
#  'EXT - 0 - FE_industry_heat_CHP_hydrogen'
#  'EXT - 0 - FE_industry_heat_CHP_oil'
#  'EXT - 0 - FE_industry_heat_CHP_waste_non_renew'
#  'EXT - 0 - FE_industry_heat_CHP_waste_non_renew_CCS'
#  'EXT - 0 - FE_industry_heat_CHP_wood'
#  'EXT - 0 - FE_industry_heat_CHP_wood_CCS'
#  'EXT - 0 - FE_industry_process_FE_other_electric'
#  'EXT - 0 - FE_industry_process_biomethane'
#  'EXT - 0 - FE_industry_process_coal'
#  'EXT - 0 - FE_industry_process_electric_boiler'
#  'EXT - 0 - FE_industry_process_heat_pump'
#  'EXT - 0 - FE_industry_process_heavy_fuel_oil'
#  'EXT - 0 - FE_industry_process_hydrogen'
#  'EXT - 0 - FE_industry_process_light_fuel_oil'
#  'EXT - 0 - FE_industry_process_natural_gas'
#  'EXT - 0 - FE_industry_process_pellet'
#  'EXT - 0 - FE_industry_process_solar'
#  'EXT - 0 - FE_industry_process_waste_non_renew'
#  'EXT - 0 - FE_industry_process_waste_renew'
#  'EXT - 0 - FE_industry_process_wood'
#  'EXT - 0 - FE_light_duty_truck_diesel'
#  'EXT - 0 - FE_light_duty_truck_electricity'
#  'EXT - 0 - FE_light_duty_truck_gas'
#  'EXT - 0 - FE_light_duty_truck_gasoline'
#  'EXT - 0 - FE_light_duty_truck_hydrogen'
#  'EXT - 0 - FE_motorcycle_electric' 'EXT - 0 - FE_motorcycle_gasoline'
#  'EXT - 0 - FE_motorcycle_hydrogen' 'EXT - 0 - FE_other_transport_diesel'
#  'EXT - 0 - FE_other_transport_electric'
#  'EXT - 0 - FE_other_transport_gasoline'
#  'EXT - 0 - FE_other_transport_hydrogen'
#  'EXT - 0 - FE_residential_FE_other_electric'
#  'EXT - 0 - FE_residential_space_heating_CHP_fuel_cell'
#  'EXT - 0 - FE_residential_space_heating_CHP_gas'
#  'EXT - 0 - FE_residential_space_heating_CHP_wood'
#  'EXT - 0 - FE_residential_space_heating_DH'
#  'EXT - 0 - FE_residential_space_heating_coal'
#  'EXT - 0 - FE_residential_space_heating_electric_boiler'
#  'EXT - 0 - FE_residential_space_heating_gas'
#  'EXT - 0 - FE_residential_space_heating_heat_pump'
#  'EXT - 0 - FE_residential_space_heating_heat_pump_gas'
#  'EXT - 0 - FE_residential_space_heating_hydrogen'
#  'EXT - 0 - FE_residential_space_heating_light_fuel_oil'
#  'EXT - 0 - FE_residential_space_heating_pellet'
#  'EXT - 0 - FE_residential_space_heating_solar'
#  'EXT - 0 - FE_residential_space_heating_wood'
#  'EXT - 0 - FE_residential_water_heating_coal'
#  'EXT - 0 - FE_residential_water_heating_electric_boiler'
#  'EXT - 0 - FE_residential_water_heating_gas'
#  'EXT - 0 - FE_residential_water_heating_heat_pump'
#  'EXT - 0 - FE_residential_water_heating_heat_pump_gas'
#  'EXT - 0 - FE_residential_water_heating_hydrogen'
#  'EXT - 0 - FE_residential_water_heating_light_fuel_oil'
#  'EXT - 0 - FE_residential_water_heating_pellet'
#  'EXT - 0 - FE_residential_water_heating_solar'
#  'EXT - 0 - FE_residential_water_heating_wood'
#  'EXT - 0 - FE_services_CHP_biogas' 'EXT - 0 - FE_services_CHP_fuel_cell'
#  'EXT - 0 - FE_services_CHP_gas' 'EXT - 0 - FE_services_CHP_hydrogen'
#  'EXT - 0 - FE_services_CHP_wood' 'EXT - 0 - FE_services_biomethane'
#  'EXT - 0 - FE_services_electric_boiler' 'EXT - 0 - FE_services_heat_pump'
#  'EXT - 0 - FE_services_hydrogen' 'EXT - 0 - FE_services_light_fuel_oil'
#  'EXT - 0 - FE_services_natural_gas'
#  'EXT - 0 - FE_services_other_electric' 'EXT - 0 - FE_services_pellet'
#  'EXT - 0 - FE_services_solar' 'EXT - 0 - FE_services_wood'
#  'EXT - 0 - FE_tram' 'EXT - 0 - FE_trolleybus'
#  'EXT - 0 - battery (industry)' 'EXT - 0 - battery (large)'
#  'EXT - 0 - battery (medium)' 'EXT - 0 - battery (multi family)'
#  'EXT - 0 - battery (services)' 'EXT - 0 - battery (single family)'
#  'EXT - 0 - biodiesel (import)' 'EXT - 0 - biodiesel, wood, FT (domestic)'
#  'EXT - 0 - biodiesel, wood, FT w CCS (domestic)'
#  'EXT - 0 - bioethanol (domestic)' 'EXT - 0 - bioethanol (import)'
#  'EXT - 0 - bioethanol, w CCS (domestic)'
#  'EXT - 0 - biogas (services CHP)'
#  'EXT - 0 - biogas, fermentation, biomass (domestic)'
#  'EXT - 0 - biogas, fermentation, sewage sludge (domestic)'
#  'EXT - 0 - biomass (CCS, BECCS)' 'EXT - 0 - biomass (CHP)'
#  'EXT - 0 - biomass (DH)' 'EXT - 0 - biomethane (domestic)'
#  'EXT - 0 - biomethane (import)' 'EXT - 0 - fossil diesel (import)'
#  'EXT - 0 - fossil gasoline (import)' 'EXT - 0 - gas (CCGT CCS)'
#  'EXT - 0 - gas (CCGT)' 'EXT - 0 - gas (CHP CCS industry)'
#  'EXT - 0 - gas (CHP DH)' 'EXT - 0 - gas (CHP fuel cell reformer)'
#  'EXT - 0 - gas (CHP industry)' 'EXT - 0 - gas (CHP single family)'
#  'EXT - 0 - gas (OCGT)' 'EXT - 0 - gas (fuel cell DH)'
#  'EXT - 0 - gas (multi family CHP fuel cell)'
#  'EXT - 0 - gas (multi family CHP)'
#  'EXT - 0 - gas (services CHP fuel cell)' 'EXT - 0 - gas (services CHP)'
#  'EXT - 0 - gas (single family CHP fuel cell)' 'EXT - 0 - geothermal'
#  'EXT - 0 - heavy fuel oil' 'EXT - 0 - hydro (pumped storage)'
#  'EXT - 0 - hydro (reservoir)' 'EXT - 0 - hydro_run_of_river'
#  'EXT - 0 - hydrogen (import)' 'EXT - 0 - hydrogen fuel cell (DH CHP)'
#  'EXT - 0 - hydrogen fuel cell (industrial CHP)'
#  'EXT - 0 - hydrogen fuel cell (services CHP)'
#  'EXT - 0 - hydrogen, PEM, large (domestic)'
#  'EXT - 0 - hydrogen, SOEC, large (domestic)'
#  'EXT - 0 - hydrogen, wood gasification (domestic)'
#  'EXT - 0 - hydrogen, wood gasification w CCS (domestic)'
#  'EXT - 0 - import' 'EXT - 0 - kerosene (import)'
#  'EXT - 0 - light_fuel_oil' 'EXT - 0 - lng (import)'
#  'EXT - 0 - low_to_medium' 'EXT - 0 - medium_to_high'
#  'EXT - 0 - natural gas (import)' 'EXT - 0 - nuclear (boiling water)'
#  'EXT - 0 - nuclear (pressure water)' 'EXT - 0 - oil (DH CHP)'
#  'EXT - 0 - oil (industry CHP)' 'EXT - 0 - oil (peak devices)'
#  'EXT - 0 - pv (industry)' 'EXT - 0 - pv (large scale)'
#  'EXT - 0 - pv (services)' 'EXT - 0 - pv residential (multi family)'
#  'EXT - 0 - pv residential (single family)'
#  'EXT - 0 - synthetic diesel (domestic)'
#  'EXT - 0 - synthetic diesel (import)'
#  'EXT - 0 - synthetic gasoline (import)'
#  'EXT - 0 - synthetic kerosene (domestic)'
#  'EXT - 0 - synthetic kerosene (import)'
#  'EXT - 0 - synthetic natural gas (domestic)'
#  'EXT - 0 - synthetic natural gas (import)'
#  'EXT - 0 - waste incineration, fossil (CHP)'
#  'EXT - 0 - waste incineration, fossil (CHP, CCS)'
#  'EXT - 0 - waste incineration, fossil (industrial)'
#  'EXT - 0 - waste incineration, fossil (industrial, CCS)'
#  'EXT - 0 - waste incineration, non-fossil (CHP)'
#  'EXT - 0 - waste incineration, non-fossil (CHP, CCS)'
#  'EXT - 0 - waste incineration, non-fossil (industrial)'
#  'EXT - 0 - waste incineration, non-fossil (industrial, CCS)'
#  'EXT - 0 - wind' 'EXT - 0 - wood (forest)'
#  'EXT - 0 - wood (landscape maintenance)' 'EXT - 0 - wood (residues)'
#  'EXT - 0 - wood (waste)'
#  'FE - final energy - Buildings - Heating - Biofuel'
#  'FE - final energy - Buildings - Heating - District Heating'
#  'FE - final energy - Buildings - Heating - Gases'
#  'FE - final energy - Buildings - Heating - H2'
#  'FE - final energy - Buildings - Heating - Heat pump'
#  'FE - final energy - Buildings - Heating - LPG'
#  'FE - final energy - Buildings - Heating - Liquid coal'
#  'FE - final energy - Buildings - Heating - Oil'
#  'FE - final energy - Buildings - Heating - Resistance'
#  'FE - final energy - Buildings - Heating - Solid Coal'
#  'FE - final energy - Buildings - Heating - Solid biomass modern'
#  'FE - final energy - Buildings - Heating - Solid biomass traditional'
#  'FE - final energy - Buildings - Heating - Syn Fuel'
#  'FE - final energy - Buildings - Other - Elec'
#  'FE - final energy - CDR - DAC - Elec'
#  'FE - final energy - CDR - DAC - Gases'
#  'FE - final energy - CDR - DAC - H2'
#  'FE - final energy - CDR - DAC - Heat'
#  'FE - final energy - CDR - Enhanced Weathering - Diesel'
#  'FE - final energy - CDR - Enhanced Weathering - Elec'
#  'FE - final energy - CDR - OAE, electric calciner - Diesel'
#  'FE - final energy - CDR - OAE, electric calciner - Elec'
#  'FE - final energy - CDR - OAE, electric calciner - H2'
#  'FE - final energy - CDR - OAE, traditional calciner - Diesel'
#  'FE - final energy - CDR - OAE, traditional calciner - Elec'
#  'FE - final energy - CDR - OAE, traditional calciner - Gases'
#  'FE - final energy - CDR - OAE, traditional calciner - Hydrogen'
#  'FE - final energy - Industry - Cement - Bio CH4'
#  'FE - final energy - Industry - Cement - Biofuel'
#  'FE - final energy - Industry - Cement - Elec'
#  'FE - final energy - Industry - Cement - H2'
#  'FE - final energy - Industry - Cement - Nat Gas'
#  'FE - final energy - Industry - Cement - Oil'
#  'FE - final energy - Industry - Cement - SNG'
#  'FE - final energy - Industry - Cement - Solid biomass'
#  'FE - final energy - Industry - Cement - Solid coal'
#  'FE - final energy - Industry - Cement - Syn Fuel'
#  'FE - final energy - Industry - Chemicals - Chemicals - Bio CH4'
#  'FE - final energy - Industry - Chemicals - Chemicals - Biofuel'
#  'FE - final energy - Industry - Chemicals - Chemicals - Elec, high temp'
#  'FE - final energy - Industry - Chemicals - Chemicals - Elec, low temp'
#  'FE - final energy - Industry - Chemicals - Chemicals - H2'
#  'FE - final energy - Industry - Chemicals - Chemicals - Liquid fossil'
#  'FE - final energy - Industry - Chemicals - Chemicals - Nat Gas'
#  'FE - final energy - Industry - Chemicals - Chemicals - SNG'
#  'FE - final energy - Industry - Chemicals - Chemicals - Solid Biomass'
#  'FE - final energy - Industry - Chemicals - Chemicals - Solid coal'
#  'FE - final energy - Industry - Chemicals - Chemicals - Syn Fuel'
#  'FE - final energy - Industry - Chemicals - Elec'
#  'FE - final energy - Industry - Non-energy use - Bio CH4'
#  'FE - final energy - Industry - Non-energy use - Biofuel'
#  'FE - final energy - Industry - Non-energy use - Biomass'
#  'FE - final energy - Industry - Non-energy use - Hydrogen'
#  'FE - final energy - Industry - Non-energy use - Liquid fossil'
#  'FE - final energy - Industry - Non-energy use - Nat Gas'
#  'FE - final energy - Industry - Non-energy use - Solid coal'
#  'FE - final energy - Industry - Non-energy use - Syn Fuel'
#  'FE - final energy - Industry - Other - Bio CH4'
#  'FE - final energy - Industry - Other - Biofuel'
#  'FE - final energy - Industry - Other - Elec'
#  'FE - final energy - Industry - Other - Elec, high temp'
#  'FE - final energy - Industry - Other - Elec, low temp'
#  'FE - final energy - Industry - Other - H2'
#  'FE - final energy - Industry - Other - Heat'
#  'FE - final energy - Industry - Other - Liquid fossil'
#  'FE - final energy - Industry - Other - Nat Gas'
#  'FE - final energy - Industry - Other - SNG'
#  'FE - final energy - Industry - Other - Solid Biomass'
#  'FE - final energy - Industry - Other - Solid coal'
#  'FE - final energy - Industry - Other - Syn Fuel'
#  'FE - final energy - Industry - Steel - All steel - Bio CH4'
#  'FE - final energy - Industry - Steel - All steel - Biofuel'
#  'FE - final energy - Industry - Steel - All steel - Elec'
#  'FE - final energy - Industry - Steel - All steel - H2'
#  'FE - final energy - Industry - Steel - All steel - Liquid fossil'
#  'FE - final energy - Industry - Steel - All steel - Nat Gas'
#  'FE - final energy - Industry - Steel - All steel - SNG'
#  'FE - final energy - Industry - Steel - All steel - Solid Biomass'
#  'FE - final energy - Industry - Steel - All steel - Solid coal'
#  'FE - final energy - Industry - Steel - All steel - Syn Fuel'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Biofuel'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Liquid fossil'
#  'FE - final energy - Transport - Freight - Domestic Shipping - Syn Fuel'
#  'FE - final energy - Transport - Freight - Int. Shipping - Biofuel'
#  'FE - final energy - Transport - Freight - Int. Shipping - Liquid fossil'
#  'FE - final energy - Transport - Freight - Int. Shipping - Syn Fuel'
#  'FE - final energy - Transport - Freight - Rail - Biofuel'
#  'FE - final energy - Transport - Freight - Rail - Elec'
#  'FE - final energy - Transport - Freight - Rail - Liquid fossil'
#  'FE - final energy - Transport - Freight - Rail - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(18t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(18t) - H2'
#  'FE - final energy - Transport - Freight - Truck(18t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(18t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(18t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(18t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(26t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(26t) - H2'
#  'FE - final energy - Transport - Freight - Truck(26t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(26t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(26t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(26t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(40t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(40t) - H2'
#  'FE - final energy - Transport - Freight - Truck(40t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(40t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(40t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(40t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Bus - Bio CH4'
#  'FE - final energy - Transport - Pass - Bus - Biofuel'
#  'FE - final energy - Transport - Pass - Bus - Elec'
#  'FE - final energy - Transport - Pass - Bus - H2'
#  'FE - final energy - Transport - Pass - Bus - Liquid fossil'
#  'FE - final energy - Transport - Pass - Bus - Nat Gas'
#  'FE - final energy - Transport - Pass - Bus - SNG'
#  'FE - final energy - Transport - Pass - Bus - Syn Fuel'
#  'FE - final energy - Transport - Pass - Compact Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Compact Car - Biofuel'
#  'FE - final energy - Transport - Pass - Compact Car - Elec'
#  'FE - final energy - Transport - Pass - Compact Car - H2'
#  'FE - final energy - Transport - Pass - Compact Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Compact Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Compact Car - SNG'
#  'FE - final energy - Transport - Pass - Compact Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - H2'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Int Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car - Elec'
#  'FE - final energy - Transport - Pass - Large Car - H2'
#  'FE - final energy - Transport - Pass - Large Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car - SNG'
#  'FE - final energy - Transport - Pass - Large Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Elec'
#  'FE - final energy - Transport - Pass - Large Car and SUV - H2'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car and SUV - SNG'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Syn Fuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Midsize Car - Biofuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Elec'
#  'FE - final energy - Transport - Pass - Midsize Car - H2'
#  'FE - final energy - Transport - Pass - Midsize Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Midsize Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Midsize Car - SNG'
#  'FE - final energy - Transport - Pass - Midsize Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Mini Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Mini Car - Biofuel'
#  'FE - final energy - Transport - Pass - Mini Car - Elec'
#  'FE - final energy - Transport - Pass - Mini Car - H2'
#  'FE - final energy - Transport - Pass - Mini Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Mini Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Mini Car - SNG'
#  'FE - final energy - Transport - Pass - Mini Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Moped - Biofuel'
#  'FE - final energy - Transport - Pass - Moped - Elec'
#  'FE - final energy - Transport - Pass - Moped - Liquid fossil'
#  'FE - final energy - Transport - Pass - Moped - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Rail - Biofuel'
#  'FE - final energy - Transport - Pass - Rail - Elec'
#  'FE - final energy - Transport - Pass - Rail - Liquid fossil'
# ...
#  'FE - final energy - Transport - Freight - Int. Shipping - Biofuel'
#  'FE - final energy - Transport - Freight - Int. Shipping - Liquid fossil'
#  'FE - final energy - Transport - Freight - Int. Shipping - Syn Fuel'
#  'FE - final energy - Transport - Freight - Rail - Biofuel'
#  'FE - final energy - Transport - Freight - Rail - Elec'
#  'FE - final energy - Transport - Freight - Rail - Liquid fossil'
#  'FE - final energy - Transport - Freight - Rail - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(0-3_5t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(18t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(18t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(18t) - H2'
#  'FE - final energy - Transport - Freight - Truck(18t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(18t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(18t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(18t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(26t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(26t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(26t) - H2'
#  'FE - final energy - Transport - Freight - Truck(26t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(26t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(26t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(26t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(40t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(40t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(40t) - H2'
#  'FE - final energy - Transport - Freight - Truck(40t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(40t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(40t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(40t) - Syn Fuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Bio CH4'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Biofuel'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Elec'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - H2'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Liquid fossil'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Nat Gas'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - SNG'
#  'FE - final energy - Transport - Freight - Truck(7_5t) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Bus - Bio CH4'
#  'FE - final energy - Transport - Pass - Bus - Biofuel'
#  'FE - final energy - Transport - Pass - Bus - Elec'
#  'FE - final energy - Transport - Pass - Bus - H2'
#  'FE - final energy - Transport - Pass - Bus - Liquid fossil'
#  'FE - final energy - Transport - Pass - Bus - Nat Gas'
#  'FE - final energy - Transport - Pass - Bus - SNG'
#  'FE - final energy - Transport - Pass - Bus - Syn Fuel'
#  'FE - final energy - Transport - Pass - Compact Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Compact Car - Biofuel'
#  'FE - final energy - Transport - Pass - Compact Car - Elec'
#  'FE - final energy - Transport - Pass - Compact Car - H2'
#  'FE - final energy - Transport - Pass - Compact Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Compact Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Compact Car - SNG'
#  'FE - final energy - Transport - Pass - Compact Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Domestic Aviation - H2'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Domestic Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Biofuel'
#  'FE - final energy - Transport - Pass - Int Aviation - Liquid fossil'
#  'FE - final energy - Transport - Pass - Int Aviation - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car - Elec'
#  'FE - final energy - Transport - Pass - Large Car - H2'
#  'FE - final energy - Transport - Pass - Large Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car - SNG'
#  'FE - final energy - Transport - Pass - Large Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Bio CH4'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Biofuel'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Elec'
#  'FE - final energy - Transport - Pass - Large Car and SUV - H2'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Liquid fossil'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Nat Gas'
#  'FE - final energy - Transport - Pass - Large Car and SUV - SNG'
#  'FE - final energy - Transport - Pass - Large Car and SUV - Syn Fuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Midsize Car - Biofuel'
#  'FE - final energy - Transport - Pass - Midsize Car - Elec'
#  'FE - final energy - Transport - Pass - Midsize Car - H2'
#  'FE - final energy - Transport - Pass - Midsize Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Midsize Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Midsize Car - SNG'
#  'FE - final energy - Transport - Pass - Midsize Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Mini Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Mini Car - Biofuel'
#  'FE - final energy - Transport - Pass - Mini Car - Elec'
#  'FE - final energy - Transport - Pass - Mini Car - H2'
#  'FE - final energy - Transport - Pass - Mini Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Mini Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Mini Car - SNG'
#  'FE - final energy - Transport - Pass - Mini Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Moped - Biofuel'
#  'FE - final energy - Transport - Pass - Moped - Elec'
#  'FE - final energy - Transport - Pass - Moped - Liquid fossil'
#  'FE - final energy - Transport - Pass - Moped - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(50-250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Biofuel'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Elec'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Liquid fossil'
#  'FE - final energy - Transport - Pass - Motorcycle(>250cc) - Syn Fuel'
#  'FE - final energy - Transport - Pass - Rail - Biofuel'
#  'FE - final energy - Transport - Pass - Rail - Elec'
#  'FE - final energy - Transport - Pass - Rail - Liquid fossil'
#  'FE - final energy - Transport - Pass - Rail - Syn Fuel'
#  'FE - final energy - Transport - Pass - Subcompact Car - Bio CH4'
#  'FE - final energy - Transport - Pass - Subcompact Car - Biofuel'
#  'FE - final energy - Transport - Pass - Subcompact Car - Elec'
#  'FE - final energy - Transport - Pass - Subcompact Car - H2'
#  'FE - final energy - Transport - Pass - Subcompact Car - Liquid fossil'
#  'FE - final energy - Transport - Pass - Subcompact Car - Nat Gas'
#  'FE - final energy - Transport - Pass - Subcompact Car - SNG'
#  'FE - final energy - Transport - Pass - Subcompact Car - Syn Fuel'
#  'FE - final energy - Transport - Pass - Van - Bio CH4'
#  'FE - final energy - Transport - Pass - Van - Biofuel'
#  'FE - final energy - Transport - Pass - Van - Elec'
#  'FE - final energy - Transport - Pass - Van - H2'
#  'FE - final energy - Transport - Pass - Van - Liquid fossil'
#  'FE - final energy - Transport - Pass - Van - Nat Gas'
#  'FE - final energy - Transport - Pass - Van - SNG'
#  'FE - final energy - Transport - Pass - Van - Syn Fuel'
#  'SE - bus - bus, battery electric' 'SE - bus - bus, compressed gas'
#  'SE - bus - bus, diesel' 'SE - bus - bus, fuel cell'
#  'SE - car - passenger car, battery electric, large'
#  'SE - car - passenger car, battery electric, medium'
#  'SE - car - passenger car, battery electric, medium SUV'
#  'SE - car - passenger car, battery electric, mini'
#  'SE - car - passenger car, battery electric, small'
#  'SE - car - passenger car, battery electric, van'
#  'SE - car - passenger car, compressed gas, large'
#  'SE - car - passenger car, compressed gas, medium'
#  'SE - car - passenger car, compressed gas, medium SUV'
#  'SE - car - passenger car, compressed gas, mini'
#  'SE - car - passenger car, compressed gas, small'
#  'SE - car - passenger car, compressed gas, van'
#  'SE - car - passenger car, fuel cell electric, large'
#  'SE - car - passenger car, fuel cell electric, medium'
#  'SE - car - passenger car, fuel cell electric, medium SUV'
#  'SE - car - passenger car, fuel cell electric, mini'
#  'SE - car - passenger car, fuel cell electric, small'
#  'SE - car - passenger car, fuel cell electric, van'
#  'SE - car - passenger car, gasoline, large'
#  'SE - car - passenger car, gasoline, medium'
#  'SE - car - passenger car, gasoline, medium SUV'
#  'SE - car - passenger car, gasoline, mini'
#  'SE - car - passenger car, gasoline, small'
#  'SE - car - passenger car, gasoline, van'
#  'SE - car - passenger car, plugin gasoline hybrid, large'
#  'SE - car - passenger car, plugin gasoline hybrid, medium'
#  'SE - car - passenger car, plugin gasoline hybrid, medium SUV'
#  'SE - car - passenger car, plugin gasoline hybrid, mini'
#  'SE - car - passenger car, plugin gasoline hybrid, small'
#  'SE - car - passenger car, plugin gasoline hybrid, van'
#  'SE - cdr - biomass power generation, with CCS'
#  'SE - cdr - direct air capture (solvent) with storage'
#  'SE - cdr - enhanced rock weathering' 'SE - cdr - ocean liming'
#  'SE - cdr - synthetic fuels, with CCS'
#  'SE - cement - cement, dry feed rotary kiln'
#  'SE - cement - cement, dry feed rotary kiln, efficient, with MEA CCS'
#  'SE - electricity - Biomass CHP' 'SE - electricity - Biomass IGCC'
#  'SE - electricity - Biomass IGCC CCS' 'SE - electricity - Coal CHP'
#  'SE - electricity - Coal IGCC' 'SE - electricity - Coal IGCC CCS'
#  'SE - electricity - Coal PC' 'SE - electricity - Gas CC'
#  'SE - electricity - Gas CC CCS' 'SE - electricity - Gas CHP'
#  'SE - electricity - Gas OC' 'SE - electricity - Gas ST'
#  'SE - electricity - Geothermal' 'SE - electricity - Hydro'
#  'SE - electricity - Nuclear' 'SE - electricity - Oil ST'
#  'SE - electricity - Solar CSP' 'SE - electricity - Solar PV Centralized'
#  'SE - electricity - Storage, Hydrogen' 'SE - electricity - Wind Offshore'
#  'SE - electricity - Wind Onshore'
#  'SE - fuels - biodiesel, from oil crops'
#  'SE - fuels - bioethanol, from grass'
#  'SE - fuels - bioethanol, from residues'
#  'SE - fuels - bioethanol, from sugar'
#  'SE - fuels - bioethanol, from wood'
#  'SE - fuels - bioethanol, from wood, with CCS' 'SE - fuels - diesel'
#  'SE - fuels - diesel, synthetic, from coal'
#  'SE - fuels - diesel, synthetic, from coal, with CCS'
#  'SE - fuels - diesel, synthetic, from electrolysis'
#  'SE - fuels - diesel, synthetic, from wood'
#  'SE - fuels - diesel, synthetic, from wood, with CCS'
#  'SE - fuels - gasoline' 'SE - fuels - hydrogen, from biomass'
#  'SE - fuels - hydrogen, from biomass, with CCS'
#  'SE - fuels - hydrogen, from coal'
#  'SE - fuels - hydrogen, from coal, with CCS'
#  'SE - fuels - hydrogen, from electrolysis, PEM'
#  'SE - fuels - hydrogen, from natural gas'
#  'SE - fuels - hydrogen, from natural gas, with CCS'
#  'SE - fuels - methane, from biomass' 'SE - fuels - natural gas'
#  'SE - fuels - petrol, synthetic, from coal'
#  'SE - fuels - petrol, synthetic, from coal, with CCS'
#  'SE - fuels - petrol, synthetic, from electrolysis'
#  'SE - heat - energy, for DACCS, from electricity'
#  'SE - heat - energy, for DACCS, from gas boiler'
#  'SE - heat - energy, for DACCS, from hydrogen turbine'
#  'SE - heat - energy, for DACCS, from other'
#  'SE - heat - energy, for EWR, from electricity'
#  'SE - heat - energy, from EWR, from diesel'
#  'SE - heat - heat, buildings, from LPG boiler'
#  'SE - heat - heat, buildings, from biomass-based methanol boiler'
#  'SE - heat - heat, buildings, from coal stove'
#  'SE - heat - heat, buildings, from coal-based methanol boiler'
#  'SE - heat - heat, buildings, from district heating'
#  'SE - heat - heat, buildings, from electric heater'
#  'SE - heat - heat, buildings, from heat pump'
#  'SE - heat - heat, buildings, from hydrogen boiler'
#  'SE - heat - heat, buildings, from light fuel oil boiler'
#  'SE - heat - heat, buildings, from natural gas'
#  'SE - heat - heat, buildings, from wood logs heater'
#  'SE - heat - heat, buildings, from wood pellets heater'
#  'SE - heat - heat, industrial, from biomass CHP'
#  'SE - heat - heat, industrial, from coal CHP'
#  'SE - heat - heat, industrial, from geothermal'
#  'SE - heat - heat, industrial, from heat pump'
#  'SE - heat - heat, industrial, from natural gas CHP'
#  'SE - heat - heat, industrial, from solar thermal'
#  'SE - ship - ship, ammonia' 'SE - ship - ship, biodiesel'
#  'SE - ship - ship, marine oil' 'SE - steel - steel - primary - BF/BOF'
#  'SE - steel - steel - primary - BF/BOF CCS'
#  'SE - steel - steel - primary - DRI'
#  'SE - steel - steel - primary - DRI CCS'
#  'SE - steel - steel - primary - H-DRI' 'SE - steel - steel - secondary'
#  'SE - train - train, diesel-electric' 'SE - train - train, electric'
#  'SE - train - train, fuel cell'
#  'SE - truck - truck, battery electric, 18 metric ton'
#  'SE - truck - truck, battery electric, 26 metric ton'
#  'SE - truck - truck, battery electric, 3.5 metric ton'
#  'SE - truck - truck, battery electric, 40 metric ton'
#  'SE - truck - truck, battery electric, 7.5 metric ton'
#  'SE - truck - truck, compressed gas, 18 metric ton'
#  'SE - truck - truck, compressed gas, 26 metric ton'
#  'SE - truck - truck, compressed gas, 3.5 metric ton'
#  'SE - truck - truck, compressed gas, 40 metric ton'
#  'SE - truck - truck, compressed gas, 7.5 metric ton'
#  'SE - truck - truck, diesel, 18 metric ton'
#  'SE - truck - truck, diesel, 26 metric ton'
#  'SE - truck - truck, diesel, 3.5 metric ton'
#  'SE - truck - truck, diesel, 40 metric ton'
#  'SE - truck - truck, diesel, 7.5 metric ton'
#  'SE - truck - truck, fuel cell electric, 18 metric ton'
#  'SE - truck - truck, fuel cell electric, 26 metric ton'
#  'SE - truck - truck, fuel cell electric, 3.5 metric ton'
#  'SE - truck - truck, fuel cell electric, 40 metric ton'
#  'SE - truck - truck, fuel cell electric, 7.5 metric ton'
#  'SE - two-wheeler - moped, battery electric'
#  'SE - two-wheeler - moped, gasoline'
#  'SE - two-wheeler - motorcycle, 50-250cc, battery electric'
#  'SE - two-wheeler - motorcycle, 50-250cc, gasoline'
#  'SE - two-wheeler - motorcycle, >250cc, battery electric'
#  'SE - two-wheeler - motorcycle, >250cc, gasoline']
# Calculating LCA results for remind...
# --- Calculating LCA results for SSP2-PkBudg1000 - SPS4...
# ------ Calculating LCA results for 2020...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2025...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2030...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2040...
# Warning: No valid output stream.
# ------ Calculating LCA results for 2050...
# Warning: No valid output stream.
# Results exported to results_remind-SSP2-PkBudg1000-stem-SPS4.gzip

# %%
import pandas as pd
from premise.geomap import Geomap
from pivottablejs import pivot_ui
from IPython.display import HTML

# %%
fps = [
    "results_remind-SSP2-PkBudg1000-stem-SPS1.gzip",
    "results_remind-SSP2-PkBudg1000-stem-SPS2.gzip",
    "results_remind-SSP2-PkBudg1000-stem-SPS3.gzip",
    "results_remind-SSP2-PkBudg1000-stem-SPS4.gzip"
]

# %%
mapping = {
    
    "EXT - 0 - FE_bus_electricity": "transport",
    "EXT - 0 - FE_bus_gas": "transport",
    "EXT - 0 - FE_bus_hydrogen": "transport",
    "EXT - 0 - FE_cars_diesel": "transport",
    "EXT - 0 - FE_cars_electricity": "transport",
    "EXT - 0 - FE_cars_gas": "transport",
    "EXT - 0 - FE_cars_gasoline": "transport",
    "EXT - 0 - FE_cars_hydrogen": "transport",
    "EXT - 0 - FE_coach_diesel": "transport",
    "EXT - 0 - FE_coach_electricity": "transport",
    "EXT - 0 - FE_coach_gas": "transport",
    "EXT - 0 - FE_coach_hydrogen": "transport",
    "EXT - 0 - FE_heavy_duty_truck_diesel": "transport",
    "EXT - 0 - FE_heavy_duty_truck_electricity": "transport",
    "EXT - 0 - FE_heavy_duty_truck_gas": "transport",
    "EXT - 0 - FE_heavy_duty_truck_hydrogen": "transport",
    "EXT - 0 - FE_light_duty_truck_diesel": "transport",
    "EXT - 0 - FE_light_duty_truck_electricity": "transport",
    "EXT - 0 - FE_light_duty_truck_gas": "transport",
    "EXT - 0 - FE_light_duty_truck_gasoline": "transport",
    "EXT - 0 - FE_light_duty_truck_hydrogen": "transport",
    "EXT - 0 - FE_motorcycle_electric": "transport",
    "EXT - 0 - FE_motorcycle_gasoline": "transport",
    "EXT - 0 - FE_motorcycle_hydrogen": "transport",
    "EXT - 0 - FE_other_transport_diesel": "transport",
    "EXT - 0 - FE_other_transport_electric": "transport",
    "EXT - 0 - FE_other_transport_hydrogen": "transport",
    "EXT - 0 - FE_tram": "transport",
    "EXT - 0 - FE_trolleybus": "transport",

    "EXT - 0 - FE_industry_heat_CHP_fuel_cell": "industry",
    "EXT - 0 - FE_industry_heat_CHP_gas": "industry",
    "EXT - 0 - FE_industry_heat_CHP_gas_CCS": "industry",
    "EXT - 0 - FE_industry_heat_CHP_hydrogen": "industry",
    "EXT - 0 - FE_industry_heat_CHP_oil": "industry",
    "EXT - 0 - FE_industry_heat_CHP_waste_non_renew": "industry",
    "EXT - 0 - FE_industry_heat_CHP_waste_non_renew_CCS": "industry",
    "EXT - 0 - FE_industry_heat_CHP_wood": "industry",
    "EXT - 0 - FE_industry_heat_CHP_wood_CCS": "industry",
    "EXT - 0 - FE_industry_heat_DH": "industry",
    "EXT - 0 - FE_industry_process_FE_other_electric": "industry",
    "EXT - 0 - FE_industry_process_coal": "industry",
    "EXT - 0 - FE_industry_process_electric_boiler": "industry",
    "EXT - 0 - FE_industry_process_heat_pump": "industry",
    "EXT - 0 - FE_industry_process_hydrogen": "industry",
    "EXT - 0 - FE_industry_process_light_fuel_oil": "industry",
    "EXT - 0 - FE_industry_process_natural_gas": "industry",
    "EXT - 0 - FE_industry_process_pellet": "industry",
    "EXT - 0 - FE_industry_process_solar": "industry",
    "EXT - 0 - FE_industry_process_waste_non_renew": "industry",
    "EXT - 0 - FE_industry_process_wood": "industry",

    "EXT - 0 - FE_residential_FE_other_electric": "residential",
    "EXT - 0 - FE_residential_space_heating_CHP_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_CHP_wood": "residential",
    "EXT - 0 - FE_residential_space_heating_DH": "residential",
    "EXT - 0 - FE_residential_space_heating_electric_boiler": "residential",
    "EXT - 0 - FE_residential_space_heating_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_heat_pump": "residential",
    "EXT - 0 - FE_residential_space_heating_heat_pump_gas": "residential",
    "EXT - 0 - FE_residential_space_heating_light_fuel_oil": "residential",
    "EXT - 0 - FE_residential_space_heating_pellet": "residential",
    "EXT - 0 - FE_residential_space_heating_solar": "residential",
    "EXT - 0 - FE_residential_space_heating_wood": "residential",
    "EXT - 0 - FE_residential_water_heating_electric_boiler": "residential",
    "EXT - 0 - FE_residential_water_heating_gas": "residential",
    "EXT - 0 - FE_residential_water_heating_heat_pump": "residential",
    "EXT - 0 - FE_residential_water_heating_heat_pump_gas": "residential",
    "EXT - 0 - FE_residential_water_heating_light_fuel_oil": "residential",
    "EXT - 0 - FE_residential_water_heating_pellet": "residential",
    "EXT - 0 - FE_residential_water_heating_solar": "residential",
    "EXT - 0 - FE_residential_water_heating_wood": "residential",

    "EXT - 0 - FE_services_CHP_biogas": "services",
    "EXT - 0 - FE_services_CHP_fuel_cell": "services",
    "EXT - 0 - FE_services_CHP_gas": "services",
    "EXT - 0 - FE_services_CHP_hydrogen": "services",
    "EXT - 0 - FE_services_CHP_wood": "services",
    "EXT - 0 - FE_services_DH": "services",
    "EXT - 0 - FE_services_FE_other_electric": "services",
    "EXT - 0 - FE_services_electric_boiler": "services",
    "EXT - 0 - FE_services_heat_pump": "services",
    "EXT - 0 - FE_services_hydrogen": "services",
    "EXT - 0 - FE_services_light_fuel_oil": "services",
    "EXT - 0 - FE_services_natural_gas": "services",
    "EXT - 0 - FE_services_pellet": "services",
    "EXT - 0 - FE_services_solar": "services",
    "EXT - 0 - FE_services_wood": "services",
}

# %%
df_final = pd.DataFrame()

for fp in fps:
    df = pd.read_parquet(fp, engine='pyarrow')
    df = df[df["value"]!=0.0]
    df = df[~df["value"].isnull()]
    df=df.reset_index()

    print(df["scenario"])
    
    geo = Geomap("remind")
    EU = geo.iam_to_ecoinvent_location("EUR")
    EU.extend(geo.iam_to_ecoinvent_location("NEU"))
    EU.remove("CH")
    EU.extend(["EUR", "NEU"])

    df.loc[df["location"].isin(EU), "location"] = "EU wo CH"
    df.loc[~df["location"].isin(["CH", "EU wo CH"]), "location"] = "RoW"

    df["sector"] = df["variable"].map(mapping)

    df = df.groupby([
        'sector', 'variable', 'year', 'region', 'model', 'scenario', 'impact_category', 'location']).sum().reset_index()
    df = df[['sector', 'variable', 'year', 'region', 'model', 'scenario', 'impact_category', 'location', "value"]]

    df["impact_category"] = df["impact_category"].str.replace("RELICS - metals extraction - ", "")
    
    df["impact_category"] = df["impact_category"].str.replace("EF v3.1 EN15804 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)", "minerals depletion")
    df["impact_category"] = df["impact_category"].str.replace("EN15804 - inventory indicators ISO21930 - ", "")
    df["impact_category"] = df["impact_category"].str.replace("Inventory results and indicators - resources - ", "")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (H) - total: ecosystem quality - ", "")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (H) - total: human health - ", "")
    
    
    df["impact_category"] = df["impact_category"].str.replace("EF v3.1 - climate change - global warming potential (GWP100)", "climate change")
    df["impact_category"] = df["impact_category"].str.replace("EF v3.1 EN15804 - climate change - global warming potential (GWP100)", "climate change")
    df["impact_category"] = df["impact_category"].str.replace("selected LCI results - resource - land occupation", "land occupation")
    df["impact_category"] = df["impact_category"].str.replace("EF v3.1 - material resources: metals/minerals - abiotic depletion potential (ADP): elements (ultimate reserves)", "natural resources (minerals and metals)")
    df["impact_category"] = df["impact_category"].str.replace("IPCC 2021 - climate change - GWP 100a, incl. H and bio CO2", "climate change")
    df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: renewable - energy content (HHV)", "renewable primary energy")
    df["impact_category"] = df["impact_category"].str.replace("Cumulative Energy Demand (CED) - energy resources: non-renewable - energy content (HHV)", "non-renewable primary energy")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (I) - total: ecosystem quality - ecosystem quality", "ecosystem impact")
    df["impact_category"] = df["impact_category"].str.replace("ReCiPe 2016 v1.03, endpoint (E) - total: human health - human health", "human health")
    df["impact_category"] = df["impact_category"].str.replace("Ecological Scarcity 2021 - total - UBP", "ecological scarcity")

    units = {
        "climate change": "kg CO2-eq.",
        "land occupation": "square meter-year",
        "natural resources (minerals and metals)": "kg Sb-eq.",
        "minerals depletion": "kg Sb-eq.",
        "use of net fresh water": "m3",
        "renewable primary energy": "MJ (HHV)",
        "non-renewable primary energy": "MJ (HHV)",
        "ecosystem impact": "species-year lost",
        "ecosystem quality": "species-year lost",
        "human health": "DALY",
        "ecological scarcity": "UBP pt"
    }
    df["unit"] = df["impact_category"].map(units)
    df.loc[df["unit"].isnull(), "unit"] = "kg"

    df_final = pd.concat([df_final, df])

    pivot_ui(df, outfile_path=f'pivottable_{fp.split("-")[-1]}.html')

    
    pivot = df.pivot_table(
        index=['sector', 'variable', 'region', 'model', 'scenario', 'impact_category', 'location', 'unit'], 
        columns='year', 
        values='value', 
        aggfunc='sum'
    ).reset_index()
    
    
    pivot.to_excel(f"{fp.replace('.gzip', '_indicators_')}.xlsx")
    
    print(fp)

pivot_ui(df_final, outfile_path=f'pivottable_all_scenarios.html')
df_final.to_excel("df_final.xlsx")
# Out:
# 0          SSP2-PkBudg1000 - SPS1
# 1          SSP2-PkBudg1000 - SPS1
# 2          SSP2-PkBudg1000 - SPS1
# 3          SSP2-PkBudg1000 - SPS1
# 4          SSP2-PkBudg1000 - SPS1
#                     ...
# 2453057    SSP2-PkBudg1000 - SPS1
# 2453058    SSP2-PkBudg1000 - SPS1
# 2453059    SSP2-PkBudg1000 - SPS1
# 2453060    SSP2-PkBudg1000 - SPS1
# 2453061    SSP2-PkBudg1000 - SPS1
# Name: scenario, Length: 2453062, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS1.gzip
# 0          SSP2-PkBudg1000 - SPS2
# 1          SSP2-PkBudg1000 - SPS2
# 2          SSP2-PkBudg1000 - SPS2
# 3          SSP2-PkBudg1000 - SPS2
# 4          SSP2-PkBudg1000 - SPS2
#                     ...
# 2479731    SSP2-PkBudg1000 - SPS2
# 2479732    SSP2-PkBudg1000 - SPS2
# 2479733    SSP2-PkBudg1000 - SPS2
# 2479734    SSP2-PkBudg1000 - SPS2
# 2479735    SSP2-PkBudg1000 - SPS2
# Name: scenario, Length: 2479736, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS2.gzip
# 0          SSP2-PkBudg1000 - SPS3
# 1          SSP2-PkBudg1000 - SPS3
# 2          SSP2-PkBudg1000 - SPS3
# 3          SSP2-PkBudg1000 - SPS3
# 4          SSP2-PkBudg1000 - SPS3
#                     ...
# 2495380    SSP2-PkBudg1000 - SPS3
# 2495381    SSP2-PkBudg1000 - SPS3
# 2495382    SSP2-PkBudg1000 - SPS3
# 2495383    SSP2-PkBudg1000 - SPS3
# 2495384    SSP2-PkBudg1000 - SPS3
# Name: scenario, Length: 2495385, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS3.gzip
# 0          SSP2-PkBudg1000 - SPS4
# 1          SSP2-PkBudg1000 - SPS4
# 2          SSP2-PkBudg1000 - SPS4
# 3          SSP2-PkBudg1000 - SPS4
# 4          SSP2-PkBudg1000 - SPS4
#                     ...
# 2422368    SSP2-PkBudg1000 - SPS4
# 2422369    SSP2-PkBudg1000 - SPS4
# 2422370    SSP2-PkBudg1000 - SPS4
# 2422371    SSP2-PkBudg1000 - SPS4
# 2422372    SSP2-PkBudg1000 - SPS4
# Name: scenario, Length: 2422373, dtype: object
# results_remind-SSP2-PkBudg1000-stem-SPS4.gzip

# %%
df_final.to_csv?
# Out:
# Signature:
# df_final.to_csv(
#     path_or_buf: 'FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None' = None,
#     *,
#     sep: 'str' = ',',
#     na_rep: 'str' = '',
#     float_format: 'str | Callable | None' = None,
#     columns: 'Sequence[Hashable] | None' = None,
#     header: 'bool_t | list[str]' = True,
#     index: 'bool_t' = True,
#     index_label: 'IndexLabel | None' = None,
#     mode: 'str' = 'w',
#     encoding: 'str | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     quoting: 'int | None' = None,
#     quotechar: 'str' = '"',
#     lineterminator: 'str | None' = None,
#     chunksize: 'int | None' = None,
#     date_format: 'str | None' = None,
#     doublequote: 'bool_t' = True,
#     escapechar: 'str | None' = None,
#     decimal: 'str' = '.',
#     errors: 'OpenFileErrors' = 'strict',
#     storage_options: 'StorageOptions | None' = None,
# ) -> 'str | None'
# Docstring:
# Write object to a comma-separated values (csv) file.
#
# Parameters
# ----------
# path_or_buf : str, path object, file-like object, or None, default None
#     String, path object (implementing os.PathLike[str]), or file-like
#     object implementing a write() function. If None, the result is
#     returned as a string. If a non-binary file object is passed, it should
#     be opened with `newline=''`, disabling universal newlines. If a binary
#     file object is passed, `mode` might need to contain a `'b'`.
# sep : str, default ','
#     String of length 1. Field delimiter for the output file.
# na_rep : str, default ''
#     Missing data representation.
# float_format : str, Callable, default None
#     Format string for floating point numbers. If a Callable is given, it takes
#     precedence over other numeric formatting parameters, like decimal.
# columns : sequence, optional
#     Columns to write.
# header : bool or list of str, default True
#     Write out the column names. If a list of strings is given it is
#     assumed to be aliases for the column names.
# index : bool, default True
#     Write row names (index).
# index_label : str or sequence, or False, default None
#     Column label for index column(s) if desired. If None is given, and
#     `header` and `index` are True, then the index names are used. A
#     sequence should be given if the object uses MultiIndex. If
#     False do not print fields for index names. Use index_label=False
#     for easier importing in R.
# mode : {'w', 'x', 'a'}, default 'w'
#     Forwarded to either `open(mode=)` or `fsspec.open(mode=)` to control
#     the file opening. Typical values include:
#
#     - 'w', truncate the file first.
#     - 'x', exclusive creation, failing if the file already exists.
#     - 'a', append to the end of file if it exists.
#
# encoding : str, optional
#     A string representing the encoding to use in the output file,
#     defaults to 'utf-8'. `encoding` is not supported if `path_or_buf`
#     is a non-binary file object.
# compression : str or dict, default 'infer'
#     For on-the-fly compression of the output data. If 'infer' and 'path_or_buf' is
#     path-like, then detect compression from the following extensions: '.gz',
#     '.bz2', '.zip', '.xz', '.zst', '.tar', '.tar.gz', '.tar.xz' or '.tar.bz2'
#     (otherwise no compression).
#     Set to ``None`` for no compression.
#     Can also be a dict with key ``'method'`` set
#     to one of {``'zip'``, ``'gzip'``, ``'bz2'``, ``'zstd'``, ``'xz'``, ``'tar'``} and
#     other key-value pairs are forwarded to
#     ``zipfile.ZipFile``, ``gzip.GzipFile``,
#     ``bz2.BZ2File``, ``zstandard.ZstdCompressor``, ``lzma.LZMAFile`` or
#     ``tarfile.TarFile``, respectively.
#     As an example, the following could be passed for faster compression and to create
#     a reproducible gzip archive:
#     ``compression={'method': 'gzip', 'compresslevel': 1, 'mtime': 1}``.
#
#     .. versionadded:: 1.5.0
#         Added support for `.tar` files.
#
#        May be a dict with key 'method' as compression mode
#        and other entries as additional compression options if
#        compression mode is 'zip'.
#
#        Passing compression options as keys in dict is
#        supported for compression modes 'gzip', 'bz2', 'zstd', and 'zip'.
# quoting : optional constant from csv module
#     Defaults to csv.QUOTE_MINIMAL. If you have set a `float_format`
#     then floats are converted to strings and thus csv.QUOTE_NONNUMERIC
#     will treat them as non-numeric.
# quotechar : str, default '\"'
#     String of length 1. Character used to quote fields.
# lineterminator : str, optional
#     The newline character or character sequence to use in the output
#     file. Defaults to `os.linesep`, which depends on the OS in which
#     this method is called ('\\n' for linux, '\\r\\n' for Windows, i.e.).
#
#     .. versionchanged:: 1.5.0
#
#         Previously was line_terminator, changed for consistency with
#         read_csv and the standard library 'csv' module.
#
# chunksize : int or None
#     Rows to write at a time.
# date_format : str, default None
#     Format string for datetime objects.
# doublequote : bool, default True
#     Control quoting of `quotechar` inside a field.
# escapechar : str, default None
#     String of length 1. Character used to escape `sep` and `quotechar`
#     when appropriate.
# decimal : str, default '.'
#     Character recognized as decimal separator. E.g. use ',' for
#     European data.
# errors : str, default 'strict'
#     Specifies how encoding and decoding errors are to be handled.
#     See the errors argument for :func:`open` for a full list
#     of options.
#
# storage_options : dict, optional
#     Extra options that make sense for a particular storage connection, e.g.
#     host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#     are forwarded to ``urllib.request.Request`` as header options. For other
#     URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#     forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#     details, and for more examples on storage options refer `here
#     <https://pandas.pydata.org/docs/user_guide/io.html?
#     highlight=storage_options#reading-writing-remote-files>`_.
#
# Returns
# -------
# None or str
#     If path_or_buf is None, returns the resulting csv format as a
#     string. Otherwise returns None.
#
# See Also
# --------
# read_csv : Load a CSV file into a DataFrame.
# to_excel : Write DataFrame to an Excel file.
#
# Examples
# --------
# Create 'out.csv' containing 'df' without indices
#
# >>> df = pd.DataFrame({'name': ['Raphael', 'Donatello'],
# ...                    'mask': ['red', 'purple'],
# ...                    'weapon': ['sai', 'bo staff']})
# >>> df.to_csv('out.csv', index=False)  # doctest: +SKIP
#
# Create 'out.zip' containing 'out.csv'
#
# >>> df.to_csv(index=False)
# 'name,mask,weapon\nRaphael,red,sai\nDonatello,purple,bo staff\n'
# >>> compression_opts = dict(method='zip',
# ...                         archive_name='out.csv')  # doctest: +SKIP
# >>> df.to_csv('out.zip', index=False,
# ...           compression=compression_opts)  # doctest: +SKIP
#
# To write a csv file to a new folder or nested folder you will first
# need to create it using either Pathlib or os:
#
# >>> from pathlib import Path  # doctest: +SKIP
# >>> filepath = Path('folder/subfolder/out.csv')  # doctest: +SKIP
# >>> filepath.parent.mkdir(parents=True, exist_ok=True)  # doctest: +SKIP
# >>> df.to_csv(filepath)  # doctest: +SKIP
#
# >>> import os  # doctest: +SKIP
# >>> os.makedirs('folder/subfolder', exist_ok=True)  # doctest: +SKIP
# >>> df.to_csv('folder/subfolder/out.csv')  # doctest: +SKIP
# File:      /opt/homebrew/Caskroom/miniforge/base/envs/pathways/lib/python3.11/site-packages/pandas/core/generic.py
# Type:      method

# %%
df_final.to_csv("envronmental_indicators.csv", encoding="latin-1", index=False)

# %%
df_final["impact_category"].unique()
# Out:
# array(['climate change', 'minerals depletion', 'use of net fresh water',
#        'land occupation', 'ecosystem quality', 'human health'],
#       dtype=object)

# %%
units = {
    "climate change": "kg CO2-eq.",
    "land occupation": "square meter-year",
    "natural resources (minerals and metals)": "kg Sb-eq.",
    "minerals depletion": "kg Sb-eq.",
    "use of net fresh water": "m3",
    "renewable primary energy": "MJ (HHV)",
    "non-renewable primary energy": "MJ (HHV)",
    "ecosystem impact": "species-year lost",
    "ecosystem quality": "species-year lost",
    "human health": "DALY",
    "ecological scarcity": "UBP pt"
}
df_final["unit"] = df_final["impact_category"].map(units)
df_final.loc[df_final["unit"].isnull(), "unit"] = "kg"

# %%
pivot = df_final.pivot_table(
    index=['variable', 'region', 'model', 'scenario', 'impact_category', 'location', 'unit'], 
    columns='year', 
    values='value', 
    aggfunc='sum'
).reset_index()

pivot.to_excel("indicators_export_all_SPS.xlsx")

# %%
p = Pathways(datapackage="remind-SSP2-PkBudg1150-stem-SPS1.zip", debug=False)
scenarios = p.scenarios.sel(region="CH", pathway=p.scenarios.pathway.values.tolist()[0], model="remind", year=2050).astype(float)
